# %%
import json

# %%
def read_jsonl(file_path: str):
    """
    Read a JSON Lines file and return its contents as a list of dictionaries.

    Args:
        file_path (str): Path to the JSON Lines file.

    Returns:
        List[dict]: A list of dictionaries representing the contents of the JSON Lines file.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        json_list = [json.loads(line) for line in lines]
    return json_list

# %%
input = read_jsonl('172222.jsonl')

input
# Out:
# [{'server': [],
#   'initializer': [['ExperimentsDataToken',
#     {'hawaii20_taller_where_panel_2024_moweb': {'subject': 'identity',
#       'buckets': 100,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'control', 'buckets': 50},
#        {'name': 'treatment', 'buckets': 50}],
#       'hashing_key': 'hawaii20_taller_where_panel_2024',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'installed_pwa': {'subject': 'visitor',
#       'buckets': 2,
#       'percent_exposed': 10,
#       'treatments': [{'name': 'control', 'buckets': 1},
#        {'name': 'treatment', 'buckets': 1}],
#       'hashing_key': 'installed_pwa',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'installed_pwa_parallel': {'subject': 'visitor',
#       'buckets': 2,
#       'percent_exposed': 10,
#       'treatments': [{'name': 'control', 'buckets': 1},
#        {'name': 'treatment', 'buckets': 1}],
#       'hashing_key': 'installed_pwa_parallel',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'experiences_host_acquisition_improved_header_cta_v2': {'subject': 'visitor',
#       'buckets': 200,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'control', 'buckets': 100},
#        {'name': 'treatment', 'buckets': 100}],
#       'hashing_key': 'experiences_host_acquisition_improved_header_cta',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'web_tcpa_compliance': {'subject': 'user',
#       'buckets': 100,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'treatment', 'buckets': 100}],
#       'hashing_key': 'web_tcpa_compliance',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'contact_us_redirect_to_contact_us_form_on_rate_limit': {'subject': 'visitor',
#       'buckets': 100,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'treatment', 'buckets': 100}],
#       'hashing_key': 'contact_us_redirect_to_contact_us_form_on_rate_limit',
#       'sitar_overrides': {},
#       'trebuchets': []}}],
#    ['CdnExperimentsToken', {}],
#    ['FlaggerReactClientDataToken',
#     {'features': {'web_prefetch_framework_v1': {'assignedTreatment': 'treatment_high',
#        'featureName': 'web_prefetch_framework_v1',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '12'},
#       'web_api_brotli_compression': {'assignedTreatment': 'control',
#        'featureName': 'web_api_brotli_compression',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '13'},
#       'jitney_reclassification_v1': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'jitney_reclassification_v1',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '1',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'react_18_cgl_new_root_api_v4': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'react_18_cgl_new_root_api_v4',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '3',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'web_improve_search_modal_close': {'assignedTreatment': 'treatment',
#        'featureName': 'web_improve_search_modal_close',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '6'},
#       'users_soa_web_oauth_facebook': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'users_soa_web_oauth_facebook',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '11',
#        'extraData': {'treatment_reason': 'out_of_experiment'}},
#       'users_soa_web_oauth_naver_v4': {'assignedTreatment': 'control',
#        'featureName': 'users_soa_web_oauth_naver_v4',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '2'},
#       'users_soa_web_oauth_wechat_v3': {'assignedTreatment': 'control',
#        'featureName': 'users_soa_web_oauth_wechat_v3',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '3'},
#       'hide_wechat_login_button_in_wechat_browser': {'assignedTreatment': 'treatment',
#        'featureName': 'hide_wechat_login_button_in_wechat_browser',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '4'},
#       'summer_2024_messaging_guest_erf': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'summer_2024_messaging_guest_erf',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '41',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'summer_2024_messaging_host_erf': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'summer_2024_messaging_host_erf',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '17',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'recently_viewed_wishlist_2024_erf_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_erf_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '23',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'china_recently_viewed_profile_entry_2024_erf_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_recently_viewed_profile_entry_2024_erf_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm3_csp_safeguard_footer_and_help_article': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm3_csp_safeguard_footer_and_help_article',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '73',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'monthly_stays_dial_v2_month_increment_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'monthly_stays_dial_v2_month_increment_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '2',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'japan_places_recommendation_web': {'assignedTreatment': 'treatment',
#        'featureName': 'japan_places_recommendation_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '24'},
#       'korea_places_recommendation_web': {'assignedTreatment': 'treatment',
#        'featureName': 'korea_places_recommendation_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '10'},
#       'hongkong_macao_taiwan_places_recommendation_web': {'assignedTreatment': 'treatment',
#        'featureName': 'hongkong_macao_taiwan_places_recommendation_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '11'},
#       'china_mainland_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_mainland_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '12',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'japan_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'japan_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '11',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'korea_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'korea_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '10',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'hongkong_macao_taiwan_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'hongkong_macao_taiwan_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'japan_expanded_search_bar_web_v2': {'assignedTreatment': 'control',
#        'featureName': 'japan_expanded_search_bar_web_v2',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '5'},
#       'korea_expanded_search_bar_web_v2': {'assignedTreatment': 'control',
#        'featureName': 'korea_expanded_search_bar_web_v2',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '6'},
#       'hongkong_macao_taiwan_expanded_search_bar_web_v2': {'assignedTreatment': 'control',
#        'featureName': 'hongkong_macao_taiwan_expanded_search_bar_web_v2',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '5'},
#       'web_prefetch_p2_map_viewport': {'assignedTreatment': 'treatment',
#        'featureName': 'web_prefetch_p2_map_viewport',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '8'},
#       'micro_flex_14_days_short_term_stay_desktop_v3': {'assignedTreatment': 'treatment',
#        'featureName': 'micro_flex_14_days_short_term_stay_desktop_v3',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '8'},
#       'micro_flex_14_days_short_term_stay_moweb_v4': {'assignedTreatment': 'treatment',
#        'featureName': 'micro_flex_14_days_short_term_stay_moweb_v4',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '10'},
#       'pdp_search_bar_with_search_params': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'pdp_search_bar_with_search_params',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '5',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'm1_checkout_video_loader_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm1_checkout_video_loader_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '40',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'return_to_quick_pay_after_resume_payment_failure': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'return_to_quick_pay_after_resume_payment_failure',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '2',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'adyen_india_upi_qr_v1': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'adyen_india_upi_qr_v1',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '8',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'identity_flow_redesign_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'identity_flow_redesign_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '7',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'identity_flow_redesign_mweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'identity_flow_redesign_mweb',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'external_linking_interstitial': {'assignedTreatment': 'treatment',
#        'featureName': 'external_linking_interstitial',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '38'},
#       'm1_upload_profile_photos_aa': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm1_upload_profile_photos_aa',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '5',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm1_upload_profile_photos': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm1_upload_profile_photos',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'cjk_passport_stats_web': {'assignedTreatment': 'treatment',
#        'featureName': 'cjk_passport_stats_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '15'},
#       'rm_cancellation_milestone_modal_v2_web_2024': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'rm_cancellation_milestone_modal_v2_web_2024',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '27',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'china_compliance_domain_v4': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_compliance_domain_v4',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '1',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'insurance_sbui_migration': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'insurance_sbui_migration',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '52',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_direct_cartes_bancaires': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_direct_cartes_bancaires',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '3',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_twint_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_twint_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '42',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_direct_adyen_eftpos': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_direct_adyen_eftpos',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '22',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_przelewy24_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_przelewy24_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '5',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_vipps_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_vipps_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_mobile_pay_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_mobile_pay_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '3',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'static_inline_map_pdp_moweb_v3': {'assignedTreatment': 'control',
#        'featureName': 'static_inline_map_pdp_moweb_v3',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '7'},
#       'enable_map_prefetching_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'enable_map_prefetching_moweb',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '26',
#        'extraData': {'treatment_reason': 'due_to_target'}},
#       'enable_map_prefetching_desktop': {'assignedTreatment': 'treatment',
#        'featureName': 'enable_map_prefetching_desktop',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '45'},
#       'map_prefetching_homepage_moweb': {'assignedTreatment': 'treatment',
#        'featureName': 'map_prefetching_homepage_moweb',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '21'},
#       'map_prefetching_homepage_desktop': {'assignedTreatment': 'treatment',
#        'featureName': 'map_prefetching_homepage_desktop',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '41'},
#       'dynamically_load_maps_library_v2': {'assignedTreatment': 'treatment',
#        'featureName': 'dynamically_load_maps_library_v2',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '13'},
#       'dragon5_price_promotion_web': {'assignedTreatment': 'treatment',
#        'featureName': 'dragon5_price_promotion_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '17'},
#       'cjk_web_pdp_highlights_compact_two_column': {'assignedTreatment': 'control',
#        'featureName': 'cjk_web_pdp_highlights_compact_two_column',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '10'},
#       'android_moweb_app_install_banner_ph_2': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'android_moweb_app_install_banner_ph_2',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'ios_moweb_app_install_banner_ph_2': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'ios_moweb_app_install_banner_ph_2',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '22',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'render_routes_to_child_routes_migration': {'assignedTreatment': 'control',
#        'featureName': 'render_routes_to_child_routes_migration',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '24'},
#       'checkout_prefetch_on_hover_v2': {'assignedTreatment': 'treatment',
#        'featureName': 'checkout_prefetch_on_hover_v2',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '14'},
#       'checkout_p5_remove_experience_upsell_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'checkout_p5_remove_experience_upsell_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '13',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'messaging_platform_viaduct_migration_messages_segment_erf_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'messaging_platform_viaduct_migration_messages_segment_erf_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '82',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'messaging_platform_viaduct_migration_thread_content_and_participants_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'messaging_platform_viaduct_migration_thread_content_and_participants_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '50',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'web_profile_photo_upload_mum': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'web_profile_photo_upload_mum',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '10',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm1_passport_profile_reordering': {'assignedTreatment': 'treatment',
#        'featureName': 'm1_passport_profile_reordering',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '16'},
#       'recently_viewed_wishlist_2024_aa_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_aa_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '4',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'recently_viewed_wishlist_2024_aa_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_aa_moweb',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '4',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'recently_viewed_wishlist_2024_erf_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_erf_moweb',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'scheduler_yield_v1': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'scheduler_yield_v1',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '19',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm3_csp_safeguard_guest_entry_profile': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm3_csp_safeguard_guest_entry_profile',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '71',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'china_recently_viewed_profile_entry_2024_erf_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_recently_viewed_profile_entry_2024_erf_moweb',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'improved_coupon_center_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'improved_coupon_center_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'search_input_one_tap_to_search': {'assignedTreatment': 'treatment',
#        'featureName': 'search_input_one_tap_to_search',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '3'},
#       'stays_search_layout_page_slot_order_map_over_feed_desktop': {'assignedTreatment': 'control',
#        'featureName': 'stays_search_layout_page_slot_order_map_over_feed_desktop',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '10'},
#       'filter_reordering_2024_moweb': {'assignedTreatment': 'roomtype_first',
#        'featureName': 'filter_reordering_2024_moweb',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '13'},
#       'filter_reordering_2024_web': {'assignedTreatment': 'roomtype_first',
#        'featureName': 'filter_reordering_2024_web',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '14'},
#       'concurrent_search_input': {'assignedTreatment': 'treatment',
#        'featureName': 'concurrent_search_input',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '15'},
#       'header_only_flush_experiment': {'assignedTreatment': 'control',
#        'featureName': 'header_only_flush_experiment',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718706765_EAMDY0ZmM1MTI3Nj',
#        'sitarVersion': '10'}},
#      'trebuchets': {'disable-scroll-driven-polyfill': {'isLaunched': False},
#       'fetch-scroll-driven-stylesheets': {'isLaunched': False},
#       'trust_ai_disable_recaptchav3': {'isLaunched': True},
#       'google_recaptcha_v3_web_logging': {'isLaunched': True},
#       'web_pps_leading_event_enabled': {'isLaunched': True},
#       'instrument_search_results_images': {'isLaunched': True},
#       'pps_web_enable_alt': {'isLaunched': False},
#       'web.niobe.normalize_read_from_cache': {'isLaunched': True},
#       'web.niobe_operation_id_standardization.kill_switch': {'isLaunched': False},
#       'kill_web_websocket_client_ping': {'isLaunched': False},
#       'web.networking_service_prefetch_kill_switch': {'isLaunched': False},
#       'trebuchet_launch_iso_client': {'isLaunched': False},
#       'kill_connection_status_provider': {'isLaunched': False},
#       'ui_state.enable_logging': {'isLaunched': False},
#       'tos_kill_switch_web': {'isLaunched': True},
#       'tos.toggle_booking_flow_check': {'isLaunched': True},
#       'kill_niobe_custom_fetch': {'isLaunched': False},
#       'monorail_deprecation.capture_v2_call_sites.web': {'isLaunched': True},
#       'monorail_deprecation.capture_v2_call_sites.web.include_common_endpoints': {'isLaunched': False},
#       'mweb_airlite_optimization_v2': {'isLaunched': False},
#       'deliver_bev_1_deprecation_force_in': {'isLaunched': False},
#       'deliver_bev_1_deprecation': {'isLaunched': False},
#       'eight_bit_belo_localhost_force': {'isLaunched': False},
#       'eight_bit_belo': {'isLaunched': True},
#       'atrium_dark_mode': {'isLaunched': True},
#       'web_niobe_websocket_visibility_disconnect': {'isLaunched': False},
#       'messaging_standard_action_history_handler': {'isLaunched': True},
#       'header_avatar_web_enabled': {'isLaunched': True},
#       'simple_search_header_logged_out_badge_v2_launch': {'isLaunched': True},
#       'web_bypass_manual_flush': {'isLaunched': True},
#       'web_bypass_manual_flush_force': {'isLaunched': False},
#       'ehlp.disable': {'isLaunched': True},
#       'profile-button.balanced-sizing': {'isLaunched': True},
#       'optimize_img_sources_beyond_viewport': {'isLaunched': True},
#       'portals_ssr_mismatch_fix': {'isLaunched': True},
#       'force_react_18_new_root_api': {'isLaunched': False},
#       'force_disable_concurrent_slots': {'isLaunched': False},
#       'force_enable_concurrent_slots': {'isLaunched': False},
#       'payments.sanctions.exclude_ruble_currency_from_selector_web': {'isLaunched': True},
#       'payins.currency.update_url_param': {'isLaunched': True},
#       'api_web_client_migration.fejax.enabled': {'isLaunched': True},
#       'api_web_client_migration.fejax.signup_login_dls_shared.kill_switch': {'isLaunched': True},
#       'niobe.rest.error_logging.kill_switch': {'isLaunched': False},
#       'hodor_sxs_enabled': {'isLaunched': False},
#       'force_in_hodor_signup_for_web': {'isLaunched': False},
#       'force_in_soa_web_login': {'isLaunched': False},
#       'users_soa_web_oauth_facebook_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_facebook_launch': {'isLaunched': False},
#       'users_soa_web_oauth_apple_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_apple_launch': {'isLaunched': True},
#       'users_soa_web_oauth_google_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_google_launch': {'isLaunched': False},
#       'users_soa_web_oauth_naver_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_naver_launch': {'isLaunched': True},
#       'users_soa_web_oauth_wechat_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_wechat_launch': {'isLaunched': True},
#       'hide_wechat_login_button_in_wechat_browser_force_in': {'isLaunched': False},
#       'hide_wechat_login_button_in_wechat_browser_launch': {'isLaunched': True},
#       'web.signup_login.china_mainland_guest_dragon5_force_in': {'isLaunched': False},
#       'web.signup_login.china_mainland_guest_dragon5': {'isLaunched': True},
#       'web.phone_recycling.force_out': {'isLaunched': False},
#       'web.phone_recycling.force_in': {'isLaunched': False},
#       'web.phone_recycling': {'isLaunched': False},
#       'web.wechat_use_oauth_popup.force_in': {'isLaunched': False},
#       'web.wechat_use_oauth_popup': {'isLaunched': True},
#       'guest_header.host_referrals_header_item_force': {'isLaunched': False},
#       'messaging_realtime_badge_guest_desktop_header': {'isLaunched': False},
#       'summer_2024_messaging_launch_web': {'isLaunched': False},
#       'summer_2024_messaging_is_home_host': {'isLaunched': False},
#       'recently_viewed_wishlist_2024_web.killswitch': {'isLaunched': False},
#       'recently_viewed_wishlist_2024_web': {'isLaunched': False},
#       'resizeobserver_no_raf_boundary': {'isLaunched': False},
#       'dragon5_china_licenses_web_force_in': {'isLaunched': False},
#       'display_german_tuv_cookie_policy_link': {'isLaunched': True},
#       'permanent_sale_opt_out_article_force_in': {'isLaunched': False},
#       'permanent_sale_opt_out_article_force_out': {'isLaunched': False},
#       'permanent_sale_opt_out_article': {'isLaunched': False},
#       'storefronts_giftcards_footer_link_enabled': {'isLaunched': True},
#       'simple_footer.enable_host_classes_link': {'isLaunched': True},
#       'ad_landing_restrict_access': {'isLaunched': False},
#       'm3_csp_safeguard_desktop_footer_force_in': {'isLaunched': False},
#       'm3_csp_safeguard_global': {'isLaunched': False},
#       'm3_csp_safeguard_desktop_footer': {'isLaunched': True},
#       'm1.monthly_stays.dial.frontend_updates': {'isLaunched': False},
#       'monthly_stays_dial_v2_month_increment_web': {'isLaunched': False},
#       'search.stays.newDayCells.killswitch': {'isLaunched': True},
#       'h2o_autocomplete_custom_num_of_results': {'isLaunched': False},
#       'hawaii20_taller_where_panel_2024_moweb': {'isLaunched': True},
#       'hawaii20_taller_where_panel_2024_moweb.force_in': {'isLaunched': False},
#       'web.search_input_h2o_autosuggestions.force_in': {'isLaunched': False},
#       'web.search_input_h2o_autocomplete.force_in': {'isLaunched': False},
#       'web.search_input_h2o_scroll_to_expand.force_in': {'isLaunched': False},
#       'filter_redesign_2024_force_web': {'isLaunched': False},
#       'micro_flex_14_days_short_term_stay_desktop.force_in': {'isLaunched': False},
#       'micro_flex_14_days_short_term_stay_moweb.force_in': {'isLaunched': False},
#       'form_factor.panel_form_factor.enabled': {'isLaunched': False},
#       'web_delay_scroll_to_top_on_client_side_routing': {'isLaunched': True},
#       'gp.web.screen_manager_future': {'isLaunched': False},
#       'gp.web.screen_manager_controls_modals': {'isLaunched': False},
#       'gp.web.magic_move': {'isLaunched': False},
#       'gp_web_stable_layouts': {'isLaunched': True},
#       'gp_jumbo_modal_hide_header': {'isLaunched': True},
#       'gp.web.set_modal_padding': {'isLaunched': True},
#       'gp.web.set_is_modal_context': {'isLaunched': True},
#       'web_scroll_direction_change_enabled': {'isLaunched': False},
#       'web_scroll_direction_change_launched': {'isLaunched': False},
#       'gp.dont_render_nav_placement_if_empty': {'isLaunched': True},
#       'page_slot_force_separate_render': {'isLaunched': True},
#       'enable_react_profiler_query_param': {'isLaunched': False},
#       'pageslot_cookie_config_override': {'isLaunched': False},
#       'gp-section-wrapper-display-contents': {'isLaunched': True},
#       'explore_gp.use_compact_layout_on_wide_pwa': {'isLaunched': False},
#       'enable_paint_containment_drawer': {'isLaunched': False},
#       'strict_search_containment_moweb': {'isLaunched': True},
#       'reduce_p2_drawer_layers': {'isLaunched': True},
#       'require_country_for_pwa': {'isLaunched': False},
#       'installed-pwa_enabled': {'isLaunched': False},
#       'installed-pwa_launched': {'isLaunched': False},
#       'a4p_header_footer_entry': {'isLaunched': True},
#       'china_m3_private_room': {'isLaunched': False},
#       'china_outbound.m3_safety_line.chatbot_entry': {'isLaunched': False},
#       'web.proative_wishlist.force': {'isLaunched': True},
#       'enable_new_native_share': {'isLaunched': True},
#       'facebook_sdk_kill_switch': {'isLaunched': False},
#       'facebook_sdk_default_off_country_toggle': {'isLaunched': True},
#       'enable_carousel_contentvisibility': {'isLaunched': False},
#       'gs.plan.saves_notification_dot': {'isLaunched': True},
#       'gs.plan.saves_notification_dot.web': {'isLaunched': True},
#       'gs.plan.save_to_list_load_more.web': {'isLaunched': True},
#       'show_multiple_saves_force_in': {'isLaunched': False},
#       'show_multiple_saves': {'isLaunched': True},
#       'should_use_acp_id_force': {'isLaunched': True},
#       'should_use_acp_id': {'isLaunched': True},
#       'kill_wishlist_index_page_prefetch_web': {'isLaunched': False},
#       'gp.core_ui.update_text_area_from_other_sections': {'isLaunched': True},
#       'stays_pdp_show_auto_expand_textarea': {'isLaunched': True},
#       'gp.forms.reset-errors-on-unmount': {'isLaunched': True},
#       'payments.quick_pay.coupon_a11y.force_in': {'isLaunched': False},
#       'payments.quick_pay.coupon_a11y.enabled': {'isLaunched': False},
#       'confirm_and_pay_loader_v2_payment_friction_force': {'isLaunched': False},
#       'confirm_and_pay_loader_v2_blocked_reservation_friction_kill_switch': {'isLaunched': False},
#       'pgng.adyen.ideal_sofort_traffic.enable': {'isLaunched': True},
#       'pgng.adyen.ideal_sofort_traffic.force_in': {'isLaunched': False},
#       'pgng.adyen.ideal_sofort_traffic.ramp': {'isLaunched': True},
#       'payments.quick_pay.use_backend_driven_icons': {'isLaunched': False},
#       'payments.quick_pay.use_generic_bank_selection_ui': {'isLaunched': False},
#       'm1_checkout_video_loader_web_force': {'isLaunched': False},
#       'm1_checkout_video_loader_web': {'isLaunched': True},
#       'payments.carte_bancaire.enabled': {'isLaunched': False},
#       'payments.eftpos.frontend.enabled': {'isLaunched': False},
#       'payments.show_resume_payment_failure_message': {'isLaunched': False},
#       'payments.adyen.india.enabled': {'isLaunched': True},
#       'payments.quickpay.use_display_name_prop_for_credit_card': {'isLaunched': True},
#       'payments.quickpay.omit_tokens': {'isLaunched': False},
#       'quick_pay.log_vaulting_errors': {'isLaunched': False},
#       'plugin_adyen_india.upi.id.vaulting.enabled': {'isLaunched': False},
#       'quick_pay.prevent_null_selected_payment_option': {'isLaunched': False},
#       'payments.regulatory_compliance.sca.fingerprint_warmup': {'isLaunched': True},
#       'payments.regulatory_compliance.enable_proactive_sca_for_new_routes': {'isLaunched': False},
#       'payments.regulatory_compliance.reuse_bt_client_token': {'isLaunched': False},
#       'qp_vaulting_soa.propagate.is_newly_vaulted': {'isLaunched': True},
#       'pgng.adyen.upi_qr_traffic.enable': {'isLaunched': False},
#       'test_adyen_cvv_only_validation_fix': {'isLaunched': False},
#       'quickpay.checkout_tokens.refetch': {'isLaunched': True},
#       'quickpay.web.get_checkout_api_request_content': {'isLaunched': True},
#       'argo.filter_out_rub': {'isLaunched': True},
#       'quickpay.postreloadfocus.currency': {'isLaunched': False},
#       'identity.web.legal_name.use_custom_fov_modal': {'isLaunched': True},
#       'api_web_client_migration.fejax.account_fov.kill_switch': {'isLaunched': True},
#       'identity.enable_handoff_to_phone_number_collected': {'isLaunched': True},
#       'web_auto_capture_redesign_force_in': {'isLaunched': False},
#       'gov_id_auto_capture_redesign': {'isLaunched': False},
#       'idv.biometrics_opt_in_force_in': {'isLaunched': False},
#       'idv.biometrics_opt_in': {'isLaunched': False},
#       'google_maps_version_3_55': {'isLaunched': False},
#       'disable_lottie_main_thread': {'isLaunched': False},
#       'enable_lottie_expressions': {'isLaunched': False},
#       'identity.safari_15_webcam_workaround_kill_switch': {'isLaunched': False},
#       'dls.avatar.monograms_color_enabled': {'isLaunched': False},
#       'only_on_image_quality_upgrade': {'isLaunched': True},
#       'only_on_image_resolution_upgrade_2560': {'isLaunched': False},
#       'only_on_image_resolution_upgrade_1920': {'isLaunched': False},
#       'only_on_image_resolution_upgrade_1680': {'isLaunched': False},
#       'only_on_image_resolution_upgrade_1440': {'isLaunched': True},
#       'pdp_image_gallery_upgrade_web': {'isLaunched': False},
#       'web.monorail.phone_number.countries': {'isLaunched': True},
#       'web.account_settings_otp_a11y_updates': {'isLaunched': True},
#       'user_profile.passport_content_m1_2024': {'isLaunched': True},
#       'm1_upload_profile_photos.edit_profile_force_in': {'isLaunched': False},
#       'm1_upload_profile_photos.edit_profile_force_out': {'isLaunched': False},
#       'm1_upload_profile_photos.umbrella': {'isLaunched': False},
#       'm1_upload_profile_photos.edit_profile': {'isLaunched': True},
#       'm1_upload_profile_photos_zoom_animation_disabled.moweb_ios': {'isLaunched': True},
#       'm1_upload_profile_photos_auto_zoom_enabled': {'isLaunched': False},
#       'm1_upload_profile_photos_learn_more_enabled': {'isLaunched': True},
#       'm1_upload_profile_photos.sign_up_force_in': {'isLaunched': False},
#       'm1_upload_profile_photos.sign_up_force_out': {'isLaunched': False},
#       'm1_upload_profile_photos.sign_up': {'isLaunched': True},
#       'm1_upload_profile_photos.booking_photo_force_in': {'isLaunched': False},
#       'm1_upload_profile_photos.booking_photo_force_out': {'isLaunched': False},
#       'm1_upload_profile_photos.booking_photo': {'isLaunched': True},
#       'dls_account_settings_payments_web_force_in': {'isLaunched': False},
#       'dls_account_settings_payments_web': {'isLaunched': True},
#       'dls_account_settings_taxes_web_force_in': {'isLaunched': False},
#       'dls_account_settings_taxes_web': {'isLaunched': True},
#       'dls_account_settings_payouts_web_force_in': {'isLaunched': False},
#       'dls_account_settings_payouts_web': {'isLaunched': True},
#       'dls_compliance_signup_login_web_force_in': {'isLaunched': False},
#       'dls_compliance_signup_login_web': {'isLaunched': False},
#       'p3_defer_modals': {'isLaunched': True},
#       'host_dls.location.google_places_api': {'isLaunched': False},
#       'map.cartographair.logging.enabled': {'isLaunched': True},
#       'p2_p3_tooltip_simplification_force_in': {'isLaunched': False},
#       'partytown_gtm_force_enabled': {'isLaunched': False},
#       'china_price_promotion_web_force_in': {'isLaunched': False},
#       'china_p2_preload_image_disabled': {'isLaunched': False},
#       'china_p2_preload_image_force_in': {'isLaunched': True},
#       'china_p2_preload_image': {'isLaunched': False},
#       'enable_listing_card_scroll_driven_animation': {'isLaunched': True},
#       'web.prefetch_passport_profile.enabled': {'isLaunched': True},
#       'm1_release.passport_stamps.launch': {'isLaunched': True},
#       'prefetch_disabled': {'isLaunched': False},
#       'enable_prefetch_on_safari': {'isLaunched': True},
#       'web.identity.losing_idv_status': {'isLaunched': True},
#       'only_on_share_button_enable_preload': {'isLaunched': True},
#       'rm_cancellation_milestone_modal_v2_force_in': {'isLaunched': False},
#       'rm_cancellation.milestone_modal_fastfollow': {'isLaunched': True},
#       'airbnb_org.simplified_account_migration.enabled': {'isLaunched': True},
#       'm1_co_travelers': {'isLaunched': True},
#       'a4w_3pb_improvement_airbnb_org': {'isLaunched': True},
#       'checkout.stays.quickpay_logs.only_log_with_CC.killswitch': {'isLaunched': False},
#       'checkout.stays.quickpay_logs.allow_duplicates_without_CC.killswitch': {'isLaunched': False},
#       'quickpay.fetch_bill_soa.web_enabled': {'isLaunched': False},
#       'desktop_p4_to_p5_fade_killswitch': {'isLaunched': False},
#       'desktop_p4_to_p5_use_new_party_prevention': {'isLaunched': False},
#       'split_stays.confirmation.prefetch_on_p5.disabled': {'isLaunched': False},
#       'pageshell_dynamic_height': {'isLaunched': True},
#       'web_default_rem_theme': {'isLaunched': True},
#       'enable_main_split_content_containment': {'isLaunched': True},
#       'disable_remarketing_data_v2': {'isLaunched': False},
#       'force_in_gtag_partytown': {'isLaunched': False},
#       'china_compliance_domain_force_in': {'isLaunched': False},
#       'china_compliance_domain_enable': {'isLaunched': True},
#       'm1_passport': {'isLaunched': True},
#       'checkout_gp_migration_prefetch_web': {'isLaunched': True},
#       'checkout_first_message_prompt_force_in': {'isLaunched': False},
#       'checkout_first_message_prompt_moweb_v1': {'isLaunched': True},
#       'checkout_first_message_prompt_web_v1': {'isLaunched': True},
#       'checkout_state_recovery_killswitch': {'isLaunched': False},
#       'checkout_p4_order_id_url_cache_enabled': {'isLaunched': True},
#       'checkout_create_route_wait_for_data_enabled': {'isLaunched': True},
#       'checkout.tools.data_mutation.killswitch': {'isLaunched': False},
#       'web.payments.monthly_stays.monthly_pricing_kill_switch': {'isLaunched': False},
#       'remove_dob_on_signups_force': {'isLaunched': False},
#       'remove_dob_on_signups': {'isLaunched': True},
#       'enable_suggested_login_force': {'isLaunched': False},
#       'enable_suggested_login': {'isLaunched': True},
#       'p4_bingo_button_updates_desktop': {'isLaunched': True},
#       'web.m1.fix_names_force_in': {'isLaunched': False},
#       'web.m1.fix_names_enabled': {'isLaunched': True},
#       'oauth_popup': {'isLaunched': True},
#       'remarketing_jitney_logging': {'isLaunched': True},
#       'disable_view_transition_navigation': {'isLaunched': False},
#       'booking.pdp.n16_guest_standards.signup.launch': {'isLaunched': False},
#       'web.signup_login_enable_admin_menu': {'isLaunched': False},
#       'booking_auth_moweb_signup_to_book_title_force': {'isLaunched': False},
#       'social_signup_skip_unmounted': {'isLaunched': True},
#       'upfront_pricing.quick_pay.remove_explantion_data': {'isLaunched': False},
#       'quick_pay.remove_explantion_data': {'isLaunched': False},
#       'payments.india.adyen.india.vaulting.enabled': {'isLaunched': False},
#       'quickpay.filter_logos': {'isLaunched': True},
#       'quickpay.fetch_bill_polling_fix.web_enabled': {'isLaunched': False},
#       'quickpay.countdown_throttling_fix.enabled': {'isLaunched': False},
#       'web_stays_pdp_guest_picker_server_driven': {'isLaunched': True},
#       'pdp_experiences_video_posttask_moweb': {'isLaunched': False},
#       'airlite.experiences.disable_video_autoplay': {'isLaunched': False},
#       'web.dragon5_pdp_review_search_relocate': {'isLaunched': True},
#       'web.experiences_pdp.new_review_modal': {'isLaunched': True},
#       'web.host_header.use_grid_layout': {'isLaunched': True},
#       'guidebook.user_profile_dropdown.force': {'isLaunched': False},
#       'messaging_realtime_badge_host_desktop_header': {'isLaunched': True},
#       'web.host_header.z_index_adjust': {'isLaunched': True},
#       'host_notifications_badging.web': {'isLaunched': True},
#       'moweb_app_switch_fab': {'isLaunched': True},
#       'messaging_realtime_badge_host_moweb_header': {'isLaunched': True},
#       'exp.host.messaging.filter_listing.launch': {'isLaunched': True},
#       'enable_map_paint_containment': {'isLaunched': True},
#       'map.google_maps.init_dom_size': {'isLaunched': True},
#       'enable_maps_copyright_containment': {'isLaunched': False},
#       'map.google_maps.tilesloaded.event': {'isLaunched': True},
#       'search_for_poi': {'isLaunched': True},
#       'auto_search_map_with_cache_force': {'isLaunched': False},
#       'auto_search_map_without_cache_force': {'isLaunched': False},
#       'search.vector_map.kill_switch': {'isLaunched': False},
#       'map_a11y_labels_desktop': {'isLaunched': False},
#       'map_a11y_labels_moweb': {'isLaunched': False},
#       'map_a11y_location_name_label': {'isLaunched': True},
#       'map_a11y_2022_moweb': {'isLaunched': True},
#       'map_a11y_2022_desktop': {'isLaunched': True},
#       'map_poi_s2_web_debug_enabled': {'isLaunched': False},
#       'map_web_debug_enabled': {'isLaunched': False},
#       'dynamically_load_maps_library': {'isLaunched': False},
#       'map_new_place_marker': {'isLaunched': False},
#       'map_google_static_map_signed_url': {'isLaunched': False},
#       'map.place_icons_missing.event': {'isLaunched': True},
#       'erf-gx.acp_id_enabled': {'isLaunched': False},
#       'gx.acp_id_enabled': {'isLaunched': True},
#       'enable_p2_hidden_controls': {'isLaunched': False},
#       'map_moweb_large_card_kill_switch': {'isLaunched': False},
#       'luxe_pdp_hide_dateless_contact': {'isLaunched': True},
#       'luxe_pdp_last_divider_fe': {'isLaunched': True},
#       'lux.luxe_pdp.new_inquiry_endpoint': {'isLaunched': True},
#       'lux.enable_pdp_layout_unification': {'isLaunched': True},
#       'elvis_hero_disable_max_height': {'isLaunched': True},
#       'pdp_optical_square_hero': {'isLaunched': False},
#       'web_m3_pdp_new_cohost': {'isLaunched': True},
#       'gx.seo_hide_subtitle_from_linking_section': {'isLaunched': False},
#       'kill-all-intercepts': {'isLaunched': False},
#       'kill-qualtrics-intercepts': {'isLaunched': False},
#       'moweb_ios_safari_photo_modal_memory_optimization': {'isLaunched': True},
#       'meet_your_host_white_background': {'isLaunched': True},
#       'stays_pdp_show_updated_business_details': {'isLaunched': True},
#       'moweb_app_install_banner_in_cookie_consent_country': {'isLaunched': True},
#       'moweb_app_install_banner_force_in': {'isLaunched': False},
#       'moweb_app_install_banner_allow_logged_in_users': {'isLaunched': True},
#       'elvis_disable_app_install_banner': {'isLaunched': True},
#       'disable_app_install_banner_homepage': {'isLaunched': True},
#       'moweb_app_install_banner_m1_behavior': {'isLaunched': True},
#       'web.pdp.hide_back_button': {'isLaunched': False},
#       'web_pdp_show_translation_nux': {'isLaunched': True},
#       'lottie_worker_migration': {'isLaunched': True},
#       'payments.gp.use_zero_mutation_for_empty_float_input': {'isLaunched': True},
#       'payments.payouts.soa_tpi_embedded_flow': {'isLaunched': True},
#       'tax.experience.us_kyc.check_referrer_enabled': {'isLaunched': False},
#       'flex_forms.field_state.require_initial_values': {'isLaunched': False},
# ...
#                   'bottomMarginPoints': None,
#                   'backgroundColorNew': None,
#                   'horizontalPadding': 'FULL_WIDTH',
#                   'maxWidth': None},
#                  {'__typename': 'SectionDetail',
#                   'sectionId': 'EDUCATION_FOOTER_BANNER_MODAL',
#                   'divider': None,
#                   'border': None,
#                   'topMarginPoints': None,
#                   'topPaddingPoints': None,
#                   'bottomPaddingPoints': None,
#                   'bottomMarginPoints': None,
#                   'backgroundColorNew': None,
#                   'horizontalPadding': 'FULL_WIDTH',
#                   'maxWidth': None}],
#                 'style': None,
#                 'formFactor': 'COMPACT',
#                 'mediaType': None}]}],
#             'screensV2': [],
#             'flows': [],
#             'metadata': {'__typename': 'StayPDPMetadata',
#              'pdpType': 'MARKETPLACE',
#              'pdpUrlType': 'ROOMS',
#              'pageTitle': None,
#              'misaId': None,
#              'isElvisListing': False,
#              'errorData': None,
#              'sharingConfig': {'__typename': 'PdpSharingConfig',
#               'title': 'Bed and breakfast in Richmond · ★4.72 · 1 bedroom · 1 bed · 1.5 shared baths',
#               'propertyType': 'Private room in bed and breakfast',
#               'location': 'Richmond',
#               'personCapacity': 2,
#               'imageUrl': 'https://a0.muscache.com/pictures/dcdba791-91ea-4885-b4b5-1fdd0f03e640.jpg',
#               'pdpLink': 'https://www.airbnb.ca/rooms/172222',
#               'shareUrl': 'https://www.airbnb.ca/rooms/172222?viralityEntryPoint=1&s=76',
#               'reviewCount': 847,
#               'starRating': 4.72},
#              'loggingContext': {'__typename': 'PdpLoggingContext',
#               'eventDataLogging': {'__typename': 'PdpEventData',
#                'listingId': '172222',
#                'page': 'p3',
#                'pdpPageType': 1,
#                'listingLat': 49.16237799375178,
#                'listingLng': -123.1622120098116,
#                'homeTier': 1,
#                'bedType': None,
#                'roomType': 'Private room',
#                'personCapacity': 2,
#                'descriptionLanguage': 'en',
#                'isSuperhost': True,
#                'pictureCount': 14,
#                'utcOffset': -28800,
#                'amenities': [3,
#                 4,
#                 7,
#                 9,
#                 137,
#                 77,
#                 79,
#                 17,
#                 145,
#                 18,
#                 146,
#                 85,
#                 23,
#                 280,
#                 89,
#                 90,
#                 27,
#                 91,
#                 92,
#                 93,
#                 30,
#                 31,
#                 35,
#                 611,
#                 100,
#                 37,
#                 101,
#                 39,
#                 103,
#                 40,
#                 41,
#                 42,
#                 44,
#                 236,
#                 45,
#                 46,
#                 47,
#                 51,
#                 627,
#                 53,
#                 251,
#                 60,
#                 61],
#                'accuracyRating': 4.85,
#                'checkinRating': 4.83,
#                'cleanlinessRating': 4.9,
#                'communicationRating': 4.82,
#                'locationRating': 4.7,
#                'valueRating': 4.8,
#                'guestSatisfactionOverall': 4.72,
#                'visibleReviewCount': '847'}},
#              'clientLoggingContext': {'__typename': 'StayPDPLoggingContext',
#               'productId': '172222',
#               'pdpType': 'MARKETPLACE',
#               'staysData': None,
#               'guestCheckoutSteps': ['ADDITIONAL_REQUESTS']},
#              'seoFeatures': {'__typename': 'SeoFeatures',
#               'androidAlternateUrl': 'android-app://com.airbnb.android/airbnb/rooms/172222',
#               'androidDeeplink': 'airbnb://rooms/172222',
#               'canonicalUrl': 'https://www.airbnb.ca/rooms/172222',
#               'iphoneDeeplink': 'airbnb://rooms/172222',
#               'metaDescription': 'Jun. 18, 2024 - Private room in bed and breakfast for $78. 23,000 + HAPPY GUESTS (all wonderful guests, except for that one ;)   * WE ARE LICENSED & INSURED  2017 North American Best Guest House (top 10)  E...',
#               'title': '28% Saving • Airport • Free Parking • Queen Bed - Bed and breakfasts for Rent in Richmond, British Columbia, Canada - Airbnb',
#               'breadcrumbDetails': [{'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/richmond-canada/stays',
#                 'linkText': 'Richmond',
#                 'searchText': 'Richmond, Canada'},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/s/homes',
#                 'linkText': 'Stays',
#                 'searchText': ''},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/',
#                 'linkText': 'Airbnb',
#                 'searchText': ''}],
#               'nearbyCities': [],
#               'neighborhoodBreadcrumbDetails': [{'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/richmond-canada/stays',
#                 'linkText': 'Richmond',
#                 'searchText': 'Richmond, Canada'},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/s/homes',
#                 'linkText': 'Stays',
#                 'searchText': ''},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/',
#                 'linkText': 'Airbnb',
#                 'searchText': ''}],
#               'ogTags': {'__typename': 'SeoOgTags',
#                'ogDescription': '28% Saving • Airport • Free Parking • Queen Bed',
#                'ogImage': 'https://a0.muscache.com/im/pictures/dcdba791-91ea-4885-b4b5-1fdd0f03e640.jpg?im_w=720&width=720&quality=70&auto=webp',
#                'ogTitle': 'Bed and breakfast in Richmond · ★4.72 · 1 bedroom · 1 bed · 1.5 shared baths',
#                'ogType': 'airbedandbreakfast:listing',
#                'ogUrl': 'https://www.airbnb.ca/rooms/172222',
#                'ogImageHeight': None,
#                'ogImageWidth': None,
#                'ogVideoUrl': None,
#                'ogVideoHeight': None,
#                'ogVideoWidth': None},
#               'otherPropertyTypes': [{'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6MTcyMjIx',
#                 'option': 'Apartments',
#                 'url': '/s/Richmond--Canada/homes?property_type_id[]=1'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6MTcyMjIw',
#                 'option': 'Houses',
#                 'url': '/s/Richmond--Canada/homes?property_type_id[]=2'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6MTcyMTg3',
#                 'option': 'Lofts',
#                 'url': '/s/Richmond--Canada/homes?property_type_id[]=35'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6MTcyMjEx',
#                 'option': 'Villas',
#                 'url': '/s/Richmond--Canada/homes?property_type_id[]=11'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6MTcyMTg1',
#                 'option': 'Condominiums',
#                 'url': '/s/Richmond--Canada/homes?property_type_id[]=37'}],
#               'propertySearchUrl': '/richmond-canada/stays',
#               'relImageSrc': 'https://a0.muscache.com/im/pictures/dcdba791-91ea-4885-b4b5-1fdd0f03e640.jpg?im_w=720&width=720&quality=70&auto=webp',
#               'twitterTags': {'__typename': 'SeoTwitterTags',
#                'twitterCard': 'photo',
#                'twitterDescription': None,
#                'twitterImage': 'https://a0.muscache.com/im/pictures/dcdba791-91ea-4885-b4b5-1fdd0f03e640.jpg?im_w=720&width=720&quality=70&auto=webp',
#                'twitterTitle': None,
#                'twitterUrl': 'https://www.airbnb.ca/rooms/172222'},
#               'indexInSearchEngines': True},
#              'initialTranslationState': None,
#              'bookingPrefetchData': {'__typename': 'PdpBookingPrefetchData',
#               'isHotelRatePlanEnabled': False,
#               'tpointContent': None,
#               'barPrice': None,
#               'canInstantBook': True,
#               'cancellationPolicies': [{'__typename': 'LegacyPdpCancellationSection',
#                 'cancellation_policy_price_type': None,
#                 'book_it_module_tooltip': 'Add your trip dates to get the cancellation details for this stay.',
#                 'cancellation_policy_id': 44,
#                 'link': '/help/article/2637',
#                 'link_text': 'Get full details',
#                 'localized_cancellation_policy_name': 'Strict',
#                 'milestones': [],
#                 'subtitles': ['Add your trip dates to get the cancellation details for this stay.'],
#                 'title': ''}],
#               'p3DepositData': None,
#               'p3MessageData': None,
#               'p3CancellationSection': {'__typename': 'LegacyPdpCancellationSection',
#                'cancellationPolicyPriceType': None},
#               'price': None,
#               'productRateSections': None,
#               'p3_display_rate': None,
#               'productItemDetail': None,
#               'ratePlanLoggingEventData': {'__typename': 'LoggingEventData',
#                'loggingId': 'ratePlanInput',
#                'experiments': None,
#                'eventData': None,
#                'eventDataSchemaName': None,
#                'section': None,
#                'component': None}}},
#             'sbuiData': {'__typename': 'StayPDPSBUIData',
#              'sectionConfiguration': {'__typename': 'StayPDPSectionConfiguration',
#               'root': {'__typename': 'PlacementGroupsPerFormFactor',
#                'sections': [{'__typename': 'SectionDataContainer',
#                  'sectionId': 'OVERVIEW_DEFAULT_V2',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp.overview_default_v2',
#                   'experiments': None,
#                   'eventData': {'productId': 'U3RheUxpc3Rpbmc6MTcyMjIy',
#                    'pdpImpressionId': 'p3_1718706765_P3TfaLw4X_9MG27X',
#                    'pdpContext': {'isGuestFavorite': 'false'}},
#                   'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpOverviewV2Section',
#                   'title': 'Room in Richmond, Canada',
#                   'overviewItems': [{'__typename': 'PdpSbuiBasicListItem',
#                     'title': '1 queen bed'},
#                    {'__typename': 'PdpSbuiBasicListItem',
#                     'title': 'Shared bathroom'}],
#                   'reviewData': {'__typename': 'PdpOverviewV2ReviewData',
#                    'reviewCountText': '847 reviews',
#                    'ratingText': '4.72',
#                    'reviewCount': '847',
#                    'isNewListing': False,
#                    'ratingAccessibilityLabel': 'Rated 4.72 out of 5 stars.',
#                    'loggingEventData': {'__typename': 'LoggingEventData',
#                     'loggingId': 'pdp.overview_default_v2',
#                     'eventData': {'productId': 'U3RheUxpc3Rpbmc6MTcyMjIy',
#                      'pdpImpressionId': 'p3_1718706765_P3TfaLw4X_9MG27X',
#                      'pdpContext': {'isGuestFavorite': 'false'}},
#                     'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                     'section': None,
#                     'component': None}}}},
#                 {'__typename': 'SectionDataContainer',
#                  'sectionId': 'HOST_OVERVIEW_DEFAULT',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp.host_overview_default',
#                   'experiments': None,
#                   'eventData': {'productId': 'U3RheUxpc3Rpbmc6MTcyMjIy',
#                    'pdpImpressionId': 'p3_1718706765_P3TfaLw4X_9MG27X',
#                    'pdpContext': {'isSuperHost': 'true', 'hostId': '821877'}},
#                   'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpHostOverviewDefaultSection',
#                   'title': 'Stay with Tammy',
#                   'overviewItems': [{'__typename': 'PdpSbuiBasicListItem',
#                     'title': 'Superhost'},
#                    {'__typename': 'PdpSbuiBasicListItem',
#                     'title': '13 years hosting'}],
#                   'hostAvatar': {'__typename': 'Avatar',
#                    'badge': 'SUPER_HOST',
#                    'scrollId': None,
#                    'avatarImage': {'__typename': 'Image',
#                     'baseUrl': 'https://a0.muscache.com/im/pictures/user/3a7d99e0-b407-4be9-8058-7cff8f794bcf.jpg',
#                     'accessibilityLabel': 'Tammy is a superhost. Learn more about Tammy.'},
#                    'loggingEventData': {'__typename': 'LoggingEventData',
#                     'loggingId': 'pdp.host_overview_default',
#                     'eventData': {'productId': 'U3RheUxpc3Rpbmc6MTcyMjIy',
#                      'pdpImpressionId': 'p3_1718706765_P3TfaLw4X_9MG27X',
#                      'pdpContext': {'isSuperHost': 'true',
#                       'hostId': '821877'}},
#                     'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                     'section': None,
#                     'component': None}}}},
#                 {'__typename': 'SectionDataContainer',
#                  'sectionId': 'LUXE_BANNER',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp_platform.luxe_banner',
#                   'experiments': None,
#                   'eventData': None,
#                   'eventDataSchemaName': None,
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpLuxeBannerSection',
#                   'accessibilityLabel': 'Airbnb Luxe',
#                   'brandDescription': 'Extraordinary homes, vetted for quality.'}}]},
#               'aircover': {'__typename': 'PlacementGroupsPerFormFactor',
#                'sections': []}}}}}}},
#         'variables': {'id': 'U3RheUxpc3Rpbmc6MTcyMjIy',
#          'pdpSectionsRequest': {'adults': '1',
#           'amenityFilters': None,
#           'bypassTargetings': False,
#           'categoryTag': None,
#           'causeId': None,
#           'children': None,
#           'disasterId': None,
#           'discountedGuestFeeVersion': None,
#           'displayExtensions': None,
#           'federatedSearchId': None,
#           'forceBoostPriorityMessageType': None,
#           'infants': None,
#           'interactionType': None,
#           'layouts': ['SIDEBAR', 'SINGLE_COLUMN'],
#           'pets': 0,
#           'pdpTypeOverride': None,
#           'photoId': None,
#           'preview': False,
#           'previousStateCheckIn': None,
#           'previousStateCheckOut': None,
#           'priceDropSource': None,
#           'privateBooking': False,
#           'promotionUuid': None,
#           'relaxedAmenityIds': None,
#           'searchId': None,
#           'selectedCancellationPolicyId': None,
#           'selectedRatePlanId': None,
#           'splitStays': None,
#           'staysBookingMigrationEnabled': False,
#           'translateUgc': None,
#           'useNewSectionWrapperApi': False,
#           'sectionIds': None,
#           'checkIn': None,
#           'checkOut': None,
#           'p3ImpressionId': 'p3_1718706765_P3TfaLw4X_9MG27X'}}}]]}],
#    ['NiobeMinimalistCacheToken', [], 1]],
#   'root > core-guest-spa > app': [],
#   'root > core-guest-spa > app > /rooms/:id(\\d+)/:subpageId?/:nestedSubpageId?': []}]

# %%
def get_listing_presentation(listing_info_json: object, listing_id: str) -> object:
    """
    Extract the presentation data from the listing information JSON.

    Args:
        listing_info_json (object): The JSON object containing listing information.
        listing_id (str): The ID of the listing.

    Returns:
        object: The presentation data or None if extraction fails.
    """
    try:
        # Extract the presentation data
        presentation = listing_info_json[0]['root > core-guest-spa'][1][1]['niobeMinimalClientData'][1][1]['data'][
            'presentation']
    except Exception as ex:
        # logging.error(f"{listing_id=} can't get presentation. Error: {ex.with_traceback()}")
        return

    return presentation

# %%
parcing_dict = get_listing_presentation(input, listing_id='172222')

with open('172222_expected_presentation.jsonl', 'w') as file:  
    file.write(json.dumps(parcing_dict) + '\n')

# %% [markdown]
# ## Expected parsed result

# %%
parsed_result = read_jsonl('172222_parsed_result.jsonl')[0]
parsed_result
# Out:
# {'listing_id': '172222',
#  'checking_in_and_out_house_rule': ['Check-in after 4:00 p.m.',
#   'Checkout before 11:00 a.m.',
#   'Self check-in with keypad'],
#  'during_your_stay_house_rule': ['2 guests maximum',
#   'No pets',
#   'Quiet hours: 11:00 p.m.–7:00 a.m.',
#   'No parties or events',
#   'No commercial photography',
#   'No smoking',
#   'Additional rules',
#   'Guests must load AirBnB app into phone.'],
#  'before_you_leave_house_rule': ['Additional requests: How’s your wonderful day? %%% Check Out Notes: %%% • 11 am check out. %%% • close & lock window. %%% • turn off lights. %%% • leave key in room & lock door.  %%% • leave cash payment for snacks, water, pop, etc.  %%% Thank You. %%% Happy Travels! %%% Tammy & Will'],
#  'bathroom_amenities': ['Bathtub',
#   'Hair dryer',
#   'Shampoo',
#   'Body soap',
#   'Hot water',
#   'Shower gel'],
#  'bedroom_and_laundry_amenities': ['Essentials',
#   'Hangers',
#   'Bed linens',
#   'Iron'],
#  'family_amenities': ['Outlet covers'],
#  'heating_and_cooling_amenities': ['Indoor fireplace', 'Heating'],
#  'privacy_and_safety_amenities': ['Lock on bedroom door',
#   'Exterior security cameras on property',
#   'Smoke alarm',
#   'Fire extinguisher',
#   'First aid kit'],
#  'internet_and_office_amenities': ['Wifi', 'Dedicated workspace'],
#  'kitchen_and_dining_amenities': ['Refrigerator',
#   'Microwave',
#   'Dishes and silverware',
#   'Mini fridge',
#   'Dishwasher',
#   'Hot water kettle',
#   'Coffee maker',
#   'Toaster',
#   'Kitchenette',
#   'Dining table'],
#  'outdoor_amenities': ['Shared patio or balcony',
#   'Shared backyard – Fully fenced',
#   'Outdoor furniture'],
#  'parking_and_facilities_amenities': ['Free driveway parking on premises – 2 spaces',
#   'Free street parking',
#   'Shared pool – available seasonally, open specific hours'],
#  'services_amenities': ['Luggage drop-off allowed', 'Self check-in', 'Keypad'],
#  'not_included_amenities': ['Kitchen',
#   'TV',
#   'Washer',
#   'Dryer',
#   'Air conditioning',
#   'Carbon monoxide alarm'],
#  'place_description': '24,000+ HAPPY GUESTS (all wonderful guests, except for that one ;) <br /><br />* WE ARE LICENSED & INSURED <br /><br />2017 North American Best Guest House (top 10)<br /><br />Exodus Adventures Award of Distinction 2016.<br /><br />2019 West Coast Guest House (Best Value)<br /><br />2015 Global Nomads Top 100 Honors<br /><br />2014 Wanderlust Destination Award<br /><br />" Voted Vancouver\'s Best BnB (website hidden) 2013"<br /><br />"Family friendly BnB "<br /><br />”it reminds us of home” - Brigitte & Gerard, Paris, France (2011)',
#  'the_space_description': "If you're looking for a clean room in a safe and convenient neighborhood close to both the airport as well as the bustling culture and plethora of dining options that central Richmond has to offer, then stay at Dejavu!<br /><br />We are just steps to the bus stop. From there it's a 5-minute ride to Richmond Center and the Canada Line which whizzes you downtown in less than half an hour. We are less than 10 minutes from Vancouver and also from the airport by car. <br />You will have use of the outdoor pool (seasonal), deck and outdoor fireplace (GAS STOVE NOT INCLUDED). Since Covid we do not offer meals. The bathroom may be shared depending on whether or not we have other guests at the same time. We offer wifi and free visitor parking.<br />••••••••<br />We have a small dog who is very friendly and well-behaved. Be forewarned, he will probably bark at you upon your arrival, but give it a couple of minutes and he'll be wanting you to play ball with him. Our little guy is non-shedding so people allergic to pet fur are typically fine around him. <br />••••••••<br />Amenities & Details:<br /><br />•Thermostat / Heater in Each Room <br />•Dishwasher <br />•Swimming Pool (Seasonal)<br />•WIFI <br />•Housekeeping <br />•Linens Provided <br />•Hot Water Kettle <br />•Microwave <br />•Parking On Site <br />•Refrigerator <br />•Soap / Shampoo <br />•Toaster  <br />•Towels <br />••••••••<br />•Grocery, Starbucks, bank, restaurants, pub, nail and hair salon all within 3 kms. <br />•We are a 5-minute drive from the Richmond Olympic Oval.<br /><br />•5 minutes by Skytrain to River Rock, Western Canada's biggest Casino Resort. Play the best table games, over 1,000 slots, high limit VIP rooms and horseracing stakes. Open 24 hours a day, seven days a week.<br /><br />•10 minutes to Whale Watching (Steveston Seabreeze Adventures)<br /><br />•Each suite has a locking door with keys, so come and go as you please. <br />••••••••<br />NOTE: We often have family staying with us, so the calendar may not be accurate. Please inquire for specific dates.",
#  'guest_access_description': '•',
#  'during_your_stay_description': 'We’re more a guest house than BnB., with a twist of Fawlty Towers sprinkled in. We don’t claim to be perfect, but we do offer an authentic experience with a regular Canadian family.',
#  'other_things_to_note_description': 'We do our best to keep nature out, but we do not use pesticides in or around the home. Sometimes nature happens and you should be ok with that before booking.',
#  'registration_number_description': '24-013097'}

# %% [markdown]
# ## Expected parsed house_rules

# %%
expected_house_rules = dict((key, parsed_result[key]) for key in parsed_result.keys() if key.endswith('_house_rule'))
expected_house_rules
# Out:
# {'checking_in_and_out_house_rule': ['Check-in after 4:00 p.m.',
#   'Checkout before 11:00 a.m.',
#   'Self check-in with keypad'],
#  'during_your_stay_house_rule': ['2 guests maximum',
#   'No pets',
#   'Quiet hours: 11:00 p.m.–7:00 a.m.',
#   'No parties or events',
#   'No commercial photography',
#   'No smoking',
#   'Additional rules',
#   'Guests must load AirBnB app into phone.'],
#  'before_you_leave_house_rule': ['Additional requests: How’s your wonderful day? %%% Check Out Notes: %%% • 11 am check out. %%% • close & lock window. %%% • turn off lights. %%% • leave key in room & lock door.  %%% • leave cash payment for snacks, water, pop, etc.  %%% Thank You. %%% Happy Travels! %%% Tammy & Will']}

# %% [markdown]
# ## Expected parsed amenities

# %%
expected_amenities = dict((key, parsed_result[key]) for key in parsed_result.keys() if key.endswith('_amenities'))
expected_amenities
# Out:
# {'bathroom_amenities': ['Bathtub',
#   'Hair dryer',
#   'Shampoo',
#   'Body soap',
#   'Hot water',
#   'Shower gel'],
#  'bedroom_and_laundry_amenities': ['Essentials',
#   'Hangers',
#   'Bed linens',
#   'Iron'],
#  'family_amenities': ['Outlet covers'],
#  'heating_and_cooling_amenities': ['Indoor fireplace', 'Heating'],
#  'privacy_and_safety_amenities': ['Lock on bedroom door',
#   'Exterior security cameras on property',
#   'Smoke alarm',
#   'Fire extinguisher',
#   'First aid kit'],
#  'internet_and_office_amenities': ['Wifi', 'Dedicated workspace'],
#  'kitchen_and_dining_amenities': ['Refrigerator',
#   'Microwave',
#   'Dishes and silverware',
#   'Mini fridge',
#   'Dishwasher',
#   'Hot water kettle',
#   'Coffee maker',
#   'Toaster',
#   'Kitchenette',
#   'Dining table'],
#  'outdoor_amenities': ['Shared patio or balcony',
#   'Shared backyard – Fully fenced',
#   'Outdoor furniture'],
#  'parking_and_facilities_amenities': ['Free driveway parking on premises – 2 spaces',
#   'Free street parking',
#   'Shared pool – available seasonally, open specific hours'],
#  'services_amenities': ['Luggage drop-off allowed', 'Self check-in', 'Keypad'],
#  'not_included_amenities': ['Kitchen',
#   'TV',
#   'Washer',
#   'Dryer',
#   'Air conditioning',
#   'Carbon monoxide alarm']}

# %% [markdown]
# ## Expected parsed description

# %%
expected_description = dict((key, parsed_result[key]) for key in parsed_result.keys() if key.endswith('_description'))
expected_description
# Out:
# {'place_description': '24,000+ HAPPY GUESTS (all wonderful guests, except for that one ;) <br /><br />* WE ARE LICENSED & INSURED <br /><br />2017 North American Best Guest House (top 10)<br /><br />Exodus Adventures Award of Distinction 2016.<br /><br />2019 West Coast Guest House (Best Value)<br /><br />2015 Global Nomads Top 100 Honors<br /><br />2014 Wanderlust Destination Award<br /><br />" Voted Vancouver\'s Best BnB (website hidden) 2013"<br /><br />"Family friendly BnB "<br /><br />”it reminds us of home” - Brigitte & Gerard, Paris, France (2011)',
#  'the_space_description': "If you're looking for a clean room in a safe and convenient neighborhood close to both the airport as well as the bustling culture and plethora of dining options that central Richmond has to offer, then stay at Dejavu!<br /><br />We are just steps to the bus stop. From there it's a 5-minute ride to Richmond Center and the Canada Line which whizzes you downtown in less than half an hour. We are less than 10 minutes from Vancouver and also from the airport by car. <br />You will have use of the outdoor pool (seasonal), deck and outdoor fireplace (GAS STOVE NOT INCLUDED). Since Covid we do not offer meals. The bathroom may be shared depending on whether or not we have other guests at the same time. We offer wifi and free visitor parking.<br />••••••••<br />We have a small dog who is very friendly and well-behaved. Be forewarned, he will probably bark at you upon your arrival, but give it a couple of minutes and he'll be wanting you to play ball with him. Our little guy is non-shedding so people allergic to pet fur are typically fine around him. <br />••••••••<br />Amenities & Details:<br /><br />•Thermostat / Heater in Each Room <br />•Dishwasher <br />•Swimming Pool (Seasonal)<br />•WIFI <br />•Housekeeping <br />•Linens Provided <br />•Hot Water Kettle <br />•Microwave <br />•Parking On Site <br />•Refrigerator <br />•Soap / Shampoo <br />•Toaster  <br />•Towels <br />••••••••<br />•Grocery, Starbucks, bank, restaurants, pub, nail and hair salon all within 3 kms. <br />•We are a 5-minute drive from the Richmond Olympic Oval.<br /><br />•5 minutes by Skytrain to River Rock, Western Canada's biggest Casino Resort. Play the best table games, over 1,000 slots, high limit VIP rooms and horseracing stakes. Open 24 hours a day, seven days a week.<br /><br />•10 minutes to Whale Watching (Steveston Seabreeze Adventures)<br /><br />•Each suite has a locking door with keys, so come and go as you please. <br />••••••••<br />NOTE: We often have family staying with us, so the calendar may not be accurate. Please inquire for specific dates.",
#  'guest_access_description': '•',
#  'during_your_stay_description': 'We’re more a guest house than BnB., with a twist of Fawlty Towers sprinkled in. We don’t claim to be perfect, but we do offer an authentic experience with a regular Canadian family.',
#  'other_things_to_note_description': 'We do our best to keep nature out, but we do not use pesticides in or around the home. Sometimes nature happens and you should be ok with that before booking.',
#  'registration_number_description': '24-013097'}

# %% [markdown]
# ## Another test example

# %%
input = read_jsonl('888757305688084444.jsonl')

input
# Out:
# [{'server': [],
#   'initializer': [['ExperimentsDataToken',
#     {'hawaii20_taller_where_panel_2024_moweb': {'subject': 'identity',
#       'buckets': 100,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'control', 'buckets': 50},
#        {'name': 'treatment', 'buckets': 50}],
#       'hashing_key': 'hawaii20_taller_where_panel_2024',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'installed_pwa': {'subject': 'visitor',
#       'buckets': 2,
#       'percent_exposed': 10,
#       'treatments': [{'name': 'control', 'buckets': 1},
#        {'name': 'treatment', 'buckets': 1}],
#       'hashing_key': 'installed_pwa',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'installed_pwa_parallel': {'subject': 'visitor',
#       'buckets': 2,
#       'percent_exposed': 10,
#       'treatments': [{'name': 'control', 'buckets': 1},
#        {'name': 'treatment', 'buckets': 1}],
#       'hashing_key': 'installed_pwa_parallel',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'experiences_host_acquisition_improved_header_cta_v2': {'subject': 'visitor',
#       'buckets': 200,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'control', 'buckets': 100},
#        {'name': 'treatment', 'buckets': 100}],
#       'hashing_key': 'experiences_host_acquisition_improved_header_cta',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'web_tcpa_compliance': {'subject': 'user',
#       'buckets': 100,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'treatment', 'buckets': 100}],
#       'hashing_key': 'web_tcpa_compliance',
#       'sitar_overrides': {},
#       'trebuchets': []},
#      'contact_us_redirect_to_contact_us_form_on_rate_limit': {'subject': 'visitor',
#       'buckets': 100,
#       'percent_exposed': 100,
#       'treatments': [{'name': 'treatment', 'buckets': 100}],
#       'hashing_key': 'contact_us_redirect_to_contact_us_form_on_rate_limit',
#       'sitar_overrides': {},
#       'trebuchets': []}}],
#    ['CdnExperimentsToken', {}],
#    ['FlaggerReactClientDataToken',
#     {'features': {'web_prefetch_framework_v1': {'assignedTreatment': 'treatment_high',
#        'featureName': 'web_prefetch_framework_v1',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '12'},
#       'web_api_brotli_compression': {'assignedTreatment': 'control',
#        'featureName': 'web_api_brotli_compression',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '13'},
#       'jitney_reclassification_v1': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'jitney_reclassification_v1',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '1',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'react_18_cgl_new_root_api_v4': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'react_18_cgl_new_root_api_v4',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '3',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'web_improve_search_modal_close': {'assignedTreatment': 'treatment',
#        'featureName': 'web_improve_search_modal_close',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '6'},
#       'users_soa_web_oauth_facebook': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'users_soa_web_oauth_facebook',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '11',
#        'extraData': {'treatment_reason': 'out_of_experiment'}},
#       'users_soa_web_oauth_naver_v4': {'assignedTreatment': 'control',
#        'featureName': 'users_soa_web_oauth_naver_v4',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '2'},
#       'users_soa_web_oauth_wechat_v3': {'assignedTreatment': 'control',
#        'featureName': 'users_soa_web_oauth_wechat_v3',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '3'},
#       'hide_wechat_login_button_in_wechat_browser': {'assignedTreatment': 'control',
#        'featureName': 'hide_wechat_login_button_in_wechat_browser',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '4'},
#       'summer_2024_messaging_guest_erf': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'summer_2024_messaging_guest_erf',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '41',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'summer_2024_messaging_host_erf': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'summer_2024_messaging_host_erf',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '17',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'recently_viewed_wishlist_2024_erf_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_erf_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '23',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'china_recently_viewed_profile_entry_2024_erf_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_recently_viewed_profile_entry_2024_erf_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm3_csp_safeguard_footer_and_help_article': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm3_csp_safeguard_footer_and_help_article',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '73',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'monthly_stays_dial_v2_month_increment_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'monthly_stays_dial_v2_month_increment_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '2',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'japan_places_recommendation_web': {'assignedTreatment': 'treatment',
#        'featureName': 'japan_places_recommendation_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '24'},
#       'korea_places_recommendation_web': {'assignedTreatment': 'treatment',
#        'featureName': 'korea_places_recommendation_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '10'},
#       'hongkong_macao_taiwan_places_recommendation_web': {'assignedTreatment': 'treatment',
#        'featureName': 'hongkong_macao_taiwan_places_recommendation_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '11'},
#       'china_mainland_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_mainland_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '12',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'japan_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'japan_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '11',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'korea_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'korea_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '10',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'hongkong_macao_taiwan_condensed_review_flow_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'hongkong_macao_taiwan_condensed_review_flow_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'japan_expanded_search_bar_web_v2': {'assignedTreatment': 'control',
#        'featureName': 'japan_expanded_search_bar_web_v2',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '5'},
#       'korea_expanded_search_bar_web_v2': {'assignedTreatment': 'control',
#        'featureName': 'korea_expanded_search_bar_web_v2',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '6'},
#       'hongkong_macao_taiwan_expanded_search_bar_web_v2': {'assignedTreatment': 'control',
#        'featureName': 'hongkong_macao_taiwan_expanded_search_bar_web_v2',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '5'},
#       'web_prefetch_p2_map_viewport': {'assignedTreatment': 'control',
#        'featureName': 'web_prefetch_p2_map_viewport',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '8'},
#       'micro_flex_14_days_short_term_stay_desktop_v3': {'assignedTreatment': 'treatment',
#        'featureName': 'micro_flex_14_days_short_term_stay_desktop_v3',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '8'},
#       'micro_flex_14_days_short_term_stay_moweb_v4': {'assignedTreatment': 'treatment',
#        'featureName': 'micro_flex_14_days_short_term_stay_moweb_v4',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '10'},
#       'pdp_search_bar_with_search_params': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'pdp_search_bar_with_search_params',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '5',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'm1_checkout_video_loader_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm1_checkout_video_loader_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '40',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'return_to_quick_pay_after_resume_payment_failure': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'return_to_quick_pay_after_resume_payment_failure',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '2',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'adyen_india_upi_qr_v1': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'adyen_india_upi_qr_v1',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '8',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'identity_flow_redesign_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'identity_flow_redesign_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '7',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'identity_flow_redesign_mweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'identity_flow_redesign_mweb',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'external_linking_interstitial': {'assignedTreatment': 'control',
#        'featureName': 'external_linking_interstitial',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '38'},
#       'm1_upload_profile_photos_aa': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm1_upload_profile_photos_aa',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '5',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm1_upload_profile_photos': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm1_upload_profile_photos',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'cjk_passport_stats_web': {'assignedTreatment': 'treatment',
#        'featureName': 'cjk_passport_stats_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '15'},
#       'rm_cancellation_milestone_modal_v2_web_2024': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'rm_cancellation_milestone_modal_v2_web_2024',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '27',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'china_compliance_domain_v4': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_compliance_domain_v4',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '1',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'insurance_sbui_migration': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'insurance_sbui_migration',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '52',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_direct_cartes_bancaires': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_direct_cartes_bancaires',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '3',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_twint_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_twint_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '42',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_direct_adyen_eftpos': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_direct_adyen_eftpos',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '22',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_przelewy24_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_przelewy24_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '5',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_vipps_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_vipps_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'payments_mobile_pay_redirect': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'payments_mobile_pay_redirect',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '3',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'static_inline_map_pdp_moweb_v3': {'assignedTreatment': 'control',
#        'featureName': 'static_inline_map_pdp_moweb_v3',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '7'},
#       'enable_map_prefetching_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'enable_map_prefetching_moweb',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '26',
#        'extraData': {'treatment_reason': 'due_to_target'}},
#       'enable_map_prefetching_desktop': {'assignedTreatment': 'treatment',
#        'featureName': 'enable_map_prefetching_desktop',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '45'},
#       'map_prefetching_homepage_moweb': {'assignedTreatment': 'treatment',
#        'featureName': 'map_prefetching_homepage_moweb',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '21'},
#       'map_prefetching_homepage_desktop': {'assignedTreatment': 'treatment',
#        'featureName': 'map_prefetching_homepage_desktop',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '41'},
#       'dynamically_load_maps_library_v2': {'assignedTreatment': 'treatment',
#        'featureName': 'dynamically_load_maps_library_v2',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '13'},
#       'dragon5_price_promotion_web': {'assignedTreatment': 'treatment',
#        'featureName': 'dragon5_price_promotion_web',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '17'},
#       'cjk_web_pdp_highlights_compact_two_column': {'assignedTreatment': 'control',
#        'featureName': 'cjk_web_pdp_highlights_compact_two_column',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '10'},
#       'android_moweb_app_install_banner_ph_2': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'android_moweb_app_install_banner_ph_2',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'ios_moweb_app_install_banner_ph_2': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'ios_moweb_app_install_banner_ph_2',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '22',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'render_routes_to_child_routes_migration': {'assignedTreatment': 'control',
#        'featureName': 'render_routes_to_child_routes_migration',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '24'},
#       'checkout_prefetch_on_hover_v2': {'assignedTreatment': 'treatment',
#        'featureName': 'checkout_prefetch_on_hover_v2',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '14'},
#       'checkout_p5_remove_experience_upsell_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'checkout_p5_remove_experience_upsell_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '13',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'messaging_platform_viaduct_migration_messages_segment_erf_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'messaging_platform_viaduct_migration_messages_segment_erf_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '82',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'messaging_platform_viaduct_migration_thread_content_and_participants_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'messaging_platform_viaduct_migration_thread_content_and_participants_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '50',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'web_profile_photo_upload_mum': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'web_profile_photo_upload_mum',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '10',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm1_passport_profile_reordering': {'assignedTreatment': 'treatment',
#        'featureName': 'm1_passport_profile_reordering',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '16'},
#       'recently_viewed_wishlist_2024_aa_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_aa_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '4',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'recently_viewed_wishlist_2024_aa_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_aa_moweb',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '4',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'recently_viewed_wishlist_2024_erf_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'recently_viewed_wishlist_2024_erf_moweb',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'exp_start_date_in_future'}},
#       'scheduler_yield_v1': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'scheduler_yield_v1',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '19',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'm3_csp_safeguard_guest_entry_profile': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'm3_csp_safeguard_guest_entry_profile',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '71',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'china_recently_viewed_profile_entry_2024_erf_moweb': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'china_recently_viewed_profile_entry_2024_erf_moweb',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '9',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'improved_coupon_center_web': {'assignedTreatment': 'treatment_unknown',
#        'featureName': 'improved_coupon_center_web',
#        'shouldLogExposure': False,
#        'subject': 'user',
#        'sitarVersion': '6',
#        'extraData': {'treatment_reason': 'subject_id_is_null_and_flag_true'}},
#       'search_input_one_tap_to_search': {'assignedTreatment': 'treatment',
#        'featureName': 'search_input_one_tap_to_search',
#        'shouldLogExposure': False,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '3'},
#       'stays_search_layout_page_slot_order_map_over_feed_desktop': {'assignedTreatment': 'control',
#        'featureName': 'stays_search_layout_page_slot_order_map_over_feed_desktop',
#        'shouldLogExposure': True,
#        'subject': 'identity',
#        'subjectId': 'misa_id_1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '10'},
#       'filter_reordering_2024_moweb': {'assignedTreatment': 'control',
#        'featureName': 'filter_reordering_2024_moweb',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '13'},
#       'filter_reordering_2024_web': {'assignedTreatment': 'control',
#        'featureName': 'filter_reordering_2024_web',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '14'},
#       'concurrent_search_input': {'assignedTreatment': 'treatment',
#        'featureName': 'concurrent_search_input',
#        'shouldLogExposure': False,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '15'},
#       'header_only_flush_experiment': {'assignedTreatment': 'treatment',
#        'featureName': 'header_only_flush_experiment',
#        'shouldLogExposure': True,
#        'subject': 'visitor',
#        'subjectId': '1718705518_EAMmViMTA1Mjc1YW',
#        'sitarVersion': '10'}},
#      'trebuchets': {'disable-scroll-driven-polyfill': {'isLaunched': False},
#       'fetch-scroll-driven-stylesheets': {'isLaunched': False},
#       'trust_ai_disable_recaptchav3': {'isLaunched': True},
#       'google_recaptcha_v3_web_logging': {'isLaunched': False},
#       'web_pps_leading_event_enabled': {'isLaunched': True},
#       'instrument_search_results_images': {'isLaunched': True},
#       'pps_web_enable_alt': {'isLaunched': False},
#       'web.niobe.normalize_read_from_cache': {'isLaunched': True},
#       'web.niobe_operation_id_standardization.kill_switch': {'isLaunched': False},
#       'kill_web_websocket_client_ping': {'isLaunched': False},
#       'web.networking_service_prefetch_kill_switch': {'isLaunched': False},
#       'trebuchet_launch_iso_client': {'isLaunched': False},
#       'kill_connection_status_provider': {'isLaunched': False},
#       'ui_state.enable_logging': {'isLaunched': False},
#       'tos_kill_switch_web': {'isLaunched': True},
#       'tos.toggle_booking_flow_check': {'isLaunched': True},
#       'kill_niobe_custom_fetch': {'isLaunched': False},
#       'monorail_deprecation.capture_v2_call_sites.web': {'isLaunched': True},
#       'monorail_deprecation.capture_v2_call_sites.web.include_common_endpoints': {'isLaunched': False},
#       'mweb_airlite_optimization_v2': {'isLaunched': False},
#       'deliver_bev_1_deprecation_force_in': {'isLaunched': False},
#       'deliver_bev_1_deprecation': {'isLaunched': False},
#       'eight_bit_belo_localhost_force': {'isLaunched': False},
#       'eight_bit_belo': {'isLaunched': True},
#       'atrium_dark_mode': {'isLaunched': True},
#       'web_niobe_websocket_visibility_disconnect': {'isLaunched': False},
#       'messaging_standard_action_history_handler': {'isLaunched': True},
#       'header_avatar_web_enabled': {'isLaunched': True},
#       'simple_search_header_logged_out_badge_v2_launch': {'isLaunched': True},
#       'web_bypass_manual_flush': {'isLaunched': True},
#       'web_bypass_manual_flush_force': {'isLaunched': False},
#       'ehlp.disable': {'isLaunched': True},
#       'profile-button.balanced-sizing': {'isLaunched': True},
#       'optimize_img_sources_beyond_viewport': {'isLaunched': True},
#       'portals_ssr_mismatch_fix': {'isLaunched': True},
#       'force_react_18_new_root_api': {'isLaunched': False},
#       'force_disable_concurrent_slots': {'isLaunched': False},
#       'force_enable_concurrent_slots': {'isLaunched': False},
#       'payments.sanctions.exclude_ruble_currency_from_selector_web': {'isLaunched': True},
#       'payins.currency.update_url_param': {'isLaunched': True},
#       'api_web_client_migration.fejax.enabled': {'isLaunched': True},
#       'api_web_client_migration.fejax.signup_login_dls_shared.kill_switch': {'isLaunched': True},
#       'niobe.rest.error_logging.kill_switch': {'isLaunched': False},
#       'hodor_sxs_enabled': {'isLaunched': False},
#       'force_in_hodor_signup_for_web': {'isLaunched': False},
#       'force_in_soa_web_login': {'isLaunched': False},
#       'users_soa_web_oauth_facebook_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_facebook_launch': {'isLaunched': False},
#       'users_soa_web_oauth_apple_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_apple_launch': {'isLaunched': True},
#       'users_soa_web_oauth_google_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_google_launch': {'isLaunched': False},
#       'users_soa_web_oauth_naver_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_naver_launch': {'isLaunched': True},
#       'users_soa_web_oauth_wechat_force_in': {'isLaunched': False},
#       'users_soa_web_oauth_wechat_launch': {'isLaunched': True},
#       'hide_wechat_login_button_in_wechat_browser_force_in': {'isLaunched': False},
#       'hide_wechat_login_button_in_wechat_browser_launch': {'isLaunched': True},
#       'web.signup_login.china_mainland_guest_dragon5_force_in': {'isLaunched': False},
#       'web.signup_login.china_mainland_guest_dragon5': {'isLaunched': True},
#       'web.phone_recycling.force_out': {'isLaunched': False},
#       'web.phone_recycling.force_in': {'isLaunched': False},
#       'web.phone_recycling': {'isLaunched': False},
#       'web.wechat_use_oauth_popup.force_in': {'isLaunched': False},
#       'web.wechat_use_oauth_popup': {'isLaunched': True},
#       'guest_header.host_referrals_header_item_force': {'isLaunched': False},
#       'messaging_realtime_badge_guest_desktop_header': {'isLaunched': True},
#       'summer_2024_messaging_launch_web': {'isLaunched': False},
#       'summer_2024_messaging_is_home_host': {'isLaunched': False},
#       'recently_viewed_wishlist_2024_web.killswitch': {'isLaunched': False},
#       'recently_viewed_wishlist_2024_web': {'isLaunched': False},
#       'resizeobserver_no_raf_boundary': {'isLaunched': False},
#       'dragon5_china_licenses_web_force_in': {'isLaunched': False},
#       'display_german_tuv_cookie_policy_link': {'isLaunched': True},
#       'permanent_sale_opt_out_article_force_in': {'isLaunched': False},
#       'permanent_sale_opt_out_article_force_out': {'isLaunched': False},
#       'permanent_sale_opt_out_article': {'isLaunched': False},
#       'storefronts_giftcards_footer_link_enabled': {'isLaunched': True},
#       'simple_footer.enable_host_classes_link': {'isLaunched': True},
#       'ad_landing_restrict_access': {'isLaunched': False},
#       'm3_csp_safeguard_desktop_footer_force_in': {'isLaunched': False},
#       'm3_csp_safeguard_global': {'isLaunched': False},
#       'm3_csp_safeguard_desktop_footer': {'isLaunched': True},
#       'm1.monthly_stays.dial.frontend_updates': {'isLaunched': False},
#       'monthly_stays_dial_v2_month_increment_web': {'isLaunched': False},
#       'search.stays.newDayCells.killswitch': {'isLaunched': True},
#       'h2o_autocomplete_custom_num_of_results': {'isLaunched': False},
#       'hawaii20_taller_where_panel_2024_moweb': {'isLaunched': True},
#       'hawaii20_taller_where_panel_2024_moweb.force_in': {'isLaunched': False},
#       'web.search_input_h2o_autosuggestions.force_in': {'isLaunched': False},
#       'web.search_input_h2o_autocomplete.force_in': {'isLaunched': False},
#       'web.search_input_h2o_scroll_to_expand.force_in': {'isLaunched': False},
#       'filter_redesign_2024_force_web': {'isLaunched': False},
#       'micro_flex_14_days_short_term_stay_desktop.force_in': {'isLaunched': False},
#       'micro_flex_14_days_short_term_stay_moweb.force_in': {'isLaunched': False},
#       'form_factor.panel_form_factor.enabled': {'isLaunched': False},
#       'web_delay_scroll_to_top_on_client_side_routing': {'isLaunched': True},
#       'gp.web.screen_manager_future': {'isLaunched': False},
#       'gp.web.screen_manager_controls_modals': {'isLaunched': False},
#       'gp.web.magic_move': {'isLaunched': False},
#       'gp_web_stable_layouts': {'isLaunched': True},
#       'gp_jumbo_modal_hide_header': {'isLaunched': True},
#       'gp.web.set_modal_padding': {'isLaunched': True},
#       'gp.web.set_is_modal_context': {'isLaunched': True},
#       'web_scroll_direction_change_enabled': {'isLaunched': False},
#       'web_scroll_direction_change_launched': {'isLaunched': False},
#       'gp.dont_render_nav_placement_if_empty': {'isLaunched': True},
#       'page_slot_force_separate_render': {'isLaunched': True},
#       'enable_react_profiler_query_param': {'isLaunched': False},
#       'pageslot_cookie_config_override': {'isLaunched': False},
#       'gp-section-wrapper-display-contents': {'isLaunched': True},
#       'explore_gp.use_compact_layout_on_wide_pwa': {'isLaunched': False},
#       'enable_paint_containment_drawer': {'isLaunched': False},
#       'strict_search_containment_moweb': {'isLaunched': True},
#       'reduce_p2_drawer_layers': {'isLaunched': True},
#       'require_country_for_pwa': {'isLaunched': False},
#       'installed-pwa_enabled': {'isLaunched': False},
#       'installed-pwa_launched': {'isLaunched': False},
#       'a4p_header_footer_entry': {'isLaunched': True},
#       'china_m3_private_room': {'isLaunched': False},
#       'china_outbound.m3_safety_line.chatbot_entry': {'isLaunched': False},
#       'web.proative_wishlist.force': {'isLaunched': True},
#       'enable_new_native_share': {'isLaunched': True},
#       'facebook_sdk_kill_switch': {'isLaunched': False},
#       'facebook_sdk_default_off_country_toggle': {'isLaunched': True},
#       'enable_carousel_contentvisibility': {'isLaunched': False},
#       'gs.plan.saves_notification_dot': {'isLaunched': True},
#       'gs.plan.saves_notification_dot.web': {'isLaunched': True},
#       'gs.plan.save_to_list_load_more.web': {'isLaunched': True},
#       'show_multiple_saves_force_in': {'isLaunched': False},
#       'show_multiple_saves': {'isLaunched': True},
#       'should_use_acp_id_force': {'isLaunched': True},
#       'should_use_acp_id': {'isLaunched': True},
#       'kill_wishlist_index_page_prefetch_web': {'isLaunched': False},
#       'gp.core_ui.update_text_area_from_other_sections': {'isLaunched': True},
#       'stays_pdp_show_auto_expand_textarea': {'isLaunched': True},
#       'gp.forms.reset-errors-on-unmount': {'isLaunched': True},
#       'payments.quick_pay.coupon_a11y.force_in': {'isLaunched': False},
#       'payments.quick_pay.coupon_a11y.enabled': {'isLaunched': False},
#       'confirm_and_pay_loader_v2_payment_friction_force': {'isLaunched': False},
#       'confirm_and_pay_loader_v2_blocked_reservation_friction_kill_switch': {'isLaunched': False},
#       'pgng.adyen.ideal_sofort_traffic.enable': {'isLaunched': True},
#       'pgng.adyen.ideal_sofort_traffic.force_in': {'isLaunched': False},
#       'pgng.adyen.ideal_sofort_traffic.ramp': {'isLaunched': True},
#       'payments.quick_pay.use_backend_driven_icons': {'isLaunched': False},
#       'payments.quick_pay.use_generic_bank_selection_ui': {'isLaunched': False},
#       'm1_checkout_video_loader_web_force': {'isLaunched': False},
#       'm1_checkout_video_loader_web': {'isLaunched': True},
#       'payments.carte_bancaire.enabled': {'isLaunched': False},
#       'payments.eftpos.frontend.enabled': {'isLaunched': False},
#       'payments.show_resume_payment_failure_message': {'isLaunched': False},
#       'payments.adyen.india.enabled': {'isLaunched': True},
#       'payments.quickpay.use_display_name_prop_for_credit_card': {'isLaunched': True},
#       'payments.quickpay.omit_tokens': {'isLaunched': False},
#       'quick_pay.log_vaulting_errors': {'isLaunched': False},
#       'plugin_adyen_india.upi.id.vaulting.enabled': {'isLaunched': False},
#       'quick_pay.prevent_null_selected_payment_option': {'isLaunched': False},
#       'payments.regulatory_compliance.sca.fingerprint_warmup': {'isLaunched': True},
#       'payments.regulatory_compliance.enable_proactive_sca_for_new_routes': {'isLaunched': False},
#       'payments.regulatory_compliance.reuse_bt_client_token': {'isLaunched': False},
#       'qp_vaulting_soa.propagate.is_newly_vaulted': {'isLaunched': True},
#       'pgng.adyen.upi_qr_traffic.enable': {'isLaunched': False},
#       'test_adyen_cvv_only_validation_fix': {'isLaunched': False},
#       'quickpay.checkout_tokens.refetch': {'isLaunched': True},
#       'quickpay.web.get_checkout_api_request_content': {'isLaunched': True},
#       'argo.filter_out_rub': {'isLaunched': True},
#       'quickpay.postreloadfocus.currency': {'isLaunched': False},
#       'identity.web.legal_name.use_custom_fov_modal': {'isLaunched': True},
#       'api_web_client_migration.fejax.account_fov.kill_switch': {'isLaunched': True},
#       'identity.enable_handoff_to_phone_number_collected': {'isLaunched': True},
#       'web_auto_capture_redesign_force_in': {'isLaunched': False},
#       'gov_id_auto_capture_redesign': {'isLaunched': False},
#       'idv.biometrics_opt_in_force_in': {'isLaunched': False},
#       'idv.biometrics_opt_in': {'isLaunched': False},
#       'google_maps_version_3_55': {'isLaunched': False},
#       'disable_lottie_main_thread': {'isLaunched': False},
#       'enable_lottie_expressions': {'isLaunched': False},
#       'identity.safari_15_webcam_workaround_kill_switch': {'isLaunched': False},
#       'dls.avatar.monograms_color_enabled': {'isLaunched': False},
#       'only_on_image_quality_upgrade': {'isLaunched': True},
#       'only_on_image_resolution_upgrade_2560': {'isLaunched': False},
#       'only_on_image_resolution_upgrade_1920': {'isLaunched': False},
#       'only_on_image_resolution_upgrade_1680': {'isLaunched': False},
#       'only_on_image_resolution_upgrade_1440': {'isLaunched': True},
#       'pdp_image_gallery_upgrade_web': {'isLaunched': False},
#       'web.monorail.phone_number.countries': {'isLaunched': True},
#       'web.account_settings_otp_a11y_updates': {'isLaunched': True},
#       'user_profile.passport_content_m1_2024': {'isLaunched': True},
#       'm1_upload_profile_photos.edit_profile_force_in': {'isLaunched': False},
#       'm1_upload_profile_photos.edit_profile_force_out': {'isLaunched': False},
#       'm1_upload_profile_photos.umbrella': {'isLaunched': False},
#       'm1_upload_profile_photos.edit_profile': {'isLaunched': True},
#       'm1_upload_profile_photos_zoom_animation_disabled.moweb_ios': {'isLaunched': True},
#       'm1_upload_profile_photos_auto_zoom_enabled': {'isLaunched': False},
#       'm1_upload_profile_photos_learn_more_enabled': {'isLaunched': True},
#       'm1_upload_profile_photos.sign_up_force_in': {'isLaunched': False},
#       'm1_upload_profile_photos.sign_up_force_out': {'isLaunched': False},
#       'm1_upload_profile_photos.sign_up': {'isLaunched': True},
#       'm1_upload_profile_photos.booking_photo_force_in': {'isLaunched': False},
#       'm1_upload_profile_photos.booking_photo_force_out': {'isLaunched': False},
#       'm1_upload_profile_photos.booking_photo': {'isLaunched': True},
#       'dls_account_settings_payments_web_force_in': {'isLaunched': False},
#       'dls_account_settings_payments_web': {'isLaunched': True},
#       'dls_account_settings_taxes_web_force_in': {'isLaunched': False},
#       'dls_account_settings_taxes_web': {'isLaunched': True},
#       'dls_account_settings_payouts_web_force_in': {'isLaunched': False},
#       'dls_account_settings_payouts_web': {'isLaunched': True},
#       'dls_compliance_signup_login_web_force_in': {'isLaunched': False},
#       'dls_compliance_signup_login_web': {'isLaunched': False},
#       'p3_defer_modals': {'isLaunched': True},
#       'host_dls.location.google_places_api': {'isLaunched': False},
#       'map.cartographair.logging.enabled': {'isLaunched': True},
#       'p2_p3_tooltip_simplification_force_in': {'isLaunched': False},
#       'partytown_gtm_force_enabled': {'isLaunched': False},
#       'china_price_promotion_web_force_in': {'isLaunched': False},
#       'china_p2_preload_image_disabled': {'isLaunched': False},
#       'china_p2_preload_image_force_in': {'isLaunched': True},
#       'china_p2_preload_image': {'isLaunched': False},
#       'enable_listing_card_scroll_driven_animation': {'isLaunched': True},
#       'web.prefetch_passport_profile.enabled': {'isLaunched': True},
#       'm1_release.passport_stamps.launch': {'isLaunched': True},
#       'prefetch_disabled': {'isLaunched': False},
#       'enable_prefetch_on_safari': {'isLaunched': True},
#       'web.identity.losing_idv_status': {'isLaunched': True},
#       'only_on_share_button_enable_preload': {'isLaunched': True},
#       'rm_cancellation_milestone_modal_v2_force_in': {'isLaunched': False},
#       'rm_cancellation.milestone_modal_fastfollow': {'isLaunched': True},
#       'airbnb_org.simplified_account_migration.enabled': {'isLaunched': True},
#       'm1_co_travelers': {'isLaunched': True},
#       'a4w_3pb_improvement_airbnb_org': {'isLaunched': True},
#       'checkout.stays.quickpay_logs.only_log_with_CC.killswitch': {'isLaunched': False},
#       'checkout.stays.quickpay_logs.allow_duplicates_without_CC.killswitch': {'isLaunched': False},
#       'quickpay.fetch_bill_soa.web_enabled': {'isLaunched': False},
#       'desktop_p4_to_p5_fade_killswitch': {'isLaunched': False},
#       'desktop_p4_to_p5_use_new_party_prevention': {'isLaunched': False},
#       'split_stays.confirmation.prefetch_on_p5.disabled': {'isLaunched': False},
#       'pageshell_dynamic_height': {'isLaunched': True},
#       'web_default_rem_theme': {'isLaunched': True},
#       'enable_main_split_content_containment': {'isLaunched': True},
#       'disable_remarketing_data_v2': {'isLaunched': False},
#       'force_in_gtag_partytown': {'isLaunched': False},
#       'china_compliance_domain_force_in': {'isLaunched': False},
#       'china_compliance_domain_enable': {'isLaunched': True},
#       'm1_passport': {'isLaunched': True},
#       'checkout_gp_migration_prefetch_web': {'isLaunched': True},
#       'checkout_first_message_prompt_force_in': {'isLaunched': False},
#       'checkout_first_message_prompt_moweb_v1': {'isLaunched': True},
#       'checkout_first_message_prompt_web_v1': {'isLaunched': True},
#       'checkout_state_recovery_killswitch': {'isLaunched': False},
#       'checkout_p4_order_id_url_cache_enabled': {'isLaunched': True},
#       'checkout_create_route_wait_for_data_enabled': {'isLaunched': True},
#       'checkout.tools.data_mutation.killswitch': {'isLaunched': False},
#       'web.payments.monthly_stays.monthly_pricing_kill_switch': {'isLaunched': False},
#       'remove_dob_on_signups_force': {'isLaunched': False},
#       'remove_dob_on_signups': {'isLaunched': True},
#       'enable_suggested_login_force': {'isLaunched': False},
#       'enable_suggested_login': {'isLaunched': True},
#       'p4_bingo_button_updates_desktop': {'isLaunched': True},
#       'web.m1.fix_names_force_in': {'isLaunched': False},
#       'web.m1.fix_names_enabled': {'isLaunched': True},
#       'oauth_popup': {'isLaunched': True},
#       'remarketing_jitney_logging': {'isLaunched': True},
#       'disable_view_transition_navigation': {'isLaunched': False},
#       'booking.pdp.n16_guest_standards.signup.launch': {'isLaunched': False},
#       'web.signup_login_enable_admin_menu': {'isLaunched': False},
#       'booking_auth_moweb_signup_to_book_title_force': {'isLaunched': False},
#       'social_signup_skip_unmounted': {'isLaunched': True},
#       'upfront_pricing.quick_pay.remove_explantion_data': {'isLaunched': False},
#       'quick_pay.remove_explantion_data': {'isLaunched': False},
#       'payments.india.adyen.india.vaulting.enabled': {'isLaunched': False},
#       'quickpay.filter_logos': {'isLaunched': True},
#       'quickpay.fetch_bill_polling_fix.web_enabled': {'isLaunched': False},
#       'quickpay.countdown_throttling_fix.enabled': {'isLaunched': False},
#       'web_stays_pdp_guest_picker_server_driven': {'isLaunched': True},
#       'pdp_experiences_video_posttask_moweb': {'isLaunched': False},
#       'airlite.experiences.disable_video_autoplay': {'isLaunched': False},
#       'web.dragon5_pdp_review_search_relocate': {'isLaunched': True},
#       'web.experiences_pdp.new_review_modal': {'isLaunched': True},
#       'web.host_header.use_grid_layout': {'isLaunched': True},
#       'guidebook.user_profile_dropdown.force': {'isLaunched': False},
#       'messaging_realtime_badge_host_desktop_header': {'isLaunched': True},
#       'web.host_header.z_index_adjust': {'isLaunched': True},
#       'host_notifications_badging.web': {'isLaunched': True},
#       'moweb_app_switch_fab': {'isLaunched': True},
#       'messaging_realtime_badge_host_moweb_header': {'isLaunched': True},
#       'exp.host.messaging.filter_listing.launch': {'isLaunched': True},
#       'enable_map_paint_containment': {'isLaunched': True},
#       'map.google_maps.init_dom_size': {'isLaunched': True},
#       'enable_maps_copyright_containment': {'isLaunched': False},
#       'map.google_maps.tilesloaded.event': {'isLaunched': True},
#       'search_for_poi': {'isLaunched': True},
#       'auto_search_map_with_cache_force': {'isLaunched': False},
#       'auto_search_map_without_cache_force': {'isLaunched': False},
#       'search.vector_map.kill_switch': {'isLaunched': False},
#       'map_a11y_labels_desktop': {'isLaunched': False},
#       'map_a11y_labels_moweb': {'isLaunched': False},
#       'map_a11y_location_name_label': {'isLaunched': True},
#       'map_a11y_2022_moweb': {'isLaunched': True},
#       'map_a11y_2022_desktop': {'isLaunched': True},
#       'map_poi_s2_web_debug_enabled': {'isLaunched': False},
#       'map_web_debug_enabled': {'isLaunched': False},
#       'dynamically_load_maps_library': {'isLaunched': False},
#       'map_new_place_marker': {'isLaunched': False},
#       'map_google_static_map_signed_url': {'isLaunched': False},
#       'map.place_icons_missing.event': {'isLaunched': True},
#       'erf-gx.acp_id_enabled': {'isLaunched': False},
#       'gx.acp_id_enabled': {'isLaunched': True},
#       'enable_p2_hidden_controls': {'isLaunched': False},
#       'map_moweb_large_card_kill_switch': {'isLaunched': False},
#       'luxe_pdp_hide_dateless_contact': {'isLaunched': True},
#       'luxe_pdp_last_divider_fe': {'isLaunched': True},
#       'lux.luxe_pdp.new_inquiry_endpoint': {'isLaunched': True},
#       'lux.enable_pdp_layout_unification': {'isLaunched': True},
#       'elvis_hero_disable_max_height': {'isLaunched': True},
#       'pdp_optical_square_hero': {'isLaunched': False},
#       'web_m3_pdp_new_cohost': {'isLaunched': True},
#       'gx.seo_hide_subtitle_from_linking_section': {'isLaunched': False},
#       'kill-all-intercepts': {'isLaunched': False},
#       'kill-qualtrics-intercepts': {'isLaunched': False},
#       'moweb_ios_safari_photo_modal_memory_optimization': {'isLaunched': True},
#       'meet_your_host_white_background': {'isLaunched': True},
#       'stays_pdp_show_updated_business_details': {'isLaunched': True},
#       'moweb_app_install_banner_in_cookie_consent_country': {'isLaunched': True},
#       'moweb_app_install_banner_force_in': {'isLaunched': False},
#       'moweb_app_install_banner_allow_logged_in_users': {'isLaunched': True},
#       'elvis_disable_app_install_banner': {'isLaunched': True},
#       'disable_app_install_banner_homepage': {'isLaunched': True},
#       'moweb_app_install_banner_m1_behavior': {'isLaunched': True},
#       'web.pdp.hide_back_button': {'isLaunched': False},
#       'web_pdp_show_translation_nux': {'isLaunched': True},
#       'lottie_worker_migration': {'isLaunched': True},
#       'payments.gp.use_zero_mutation_for_empty_float_input': {'isLaunched': True},
#       'payments.payouts.soa_tpi_embedded_flow': {'isLaunched': True},
#       'tax.experience.us_kyc.check_referrer_enabled': {'isLaunched': False},
#       'flex_forms.field_state.require_initial_values': {'isLaunched': False},
# ...
#               'starRating': 5},
#              'loggingContext': {'__typename': 'PdpLoggingContext',
#               'eventDataLogging': {'__typename': 'PdpEventData',
#                'listingId': '888757305688084444',
#                'page': 'p3',
#                'pdpPageType': 1,
#                'listingLat': 49.32194346240714,
#                'listingLng': -122.99735508587189,
#                'homeTier': 1,
#                'bedType': None,
#                'roomType': 'Entire home/apt',
#                'personCapacity': 4,
#                'descriptionLanguage': 'en',
#                'isSuperhost': True,
#                'pictureCount': 14,
#                'utcOffset': -28800,
#                'amenities': [64,
#                 1,
#                 4,
#                 8,
#                 72,
#                 9,
#                 73,
#                 137,
#                 74,
#                 77,
#                 79,
#                 657,
#                 85,
#                 86,
#                 23,
#                 89,
#                 665,
#                 90,
#                 91,
#                 92,
#                 93,
#                 30,
#                 94,
#                 95,
#                 671,
#                 96,
#                 672,
#                 33,
#                 34,
#                 35,
#                 36,
#                 100,
#                 39,
#                 167,
#                 40,
#                 41,
#                 44,
#                 236,
#                 45,
#                 47,
#                 51,
#                 179,
#                 308,
#                 500,
#                 53,
#                 57,
#                 510],
#                'accuracyRating': 5,
#                'checkinRating': 5,
#                'cleanlinessRating': 5,
#                'communicationRating': 5,
#                'locationRating': 4.93,
#                'valueRating': 4.96,
#                'guestSatisfactionOverall': 5,
#                'visibleReviewCount': '28'}},
#              'clientLoggingContext': {'__typename': 'StayPDPLoggingContext',
#               'productId': '888757305688084444',
#               'pdpType': 'MARKETPLACE',
#               'staysData': None,
#               'guestCheckoutSteps': []},
#              'seoFeatures': {'__typename': 'SeoFeatures',
#               'androidAlternateUrl': 'android-app://com.airbnb.android/airbnb/rooms/888757305688084444',
#               'androidDeeplink': 'airbnb://rooms/888757305688084444',
#               'canonicalUrl': 'https://www.airbnb.ca/rooms/888757305688084444',
#               'iphoneDeeplink': 'airbnb://rooms/888757305688084444',
#               'metaDescription': 'Jun. 18, 2024 - Entire guest suite for $130. Use our newly renovated place as your basecamp for your North Vancouver adventures. Located in Blueridge at the foot of Mt Seymour, close to world ...',
#               'title': 'Evergreen Suite - new cozy 1BR - Guest suites for Rent in North Vancouver, British Columbia, Canada - Airbnb',
#               'breadcrumbDetails': [{'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/north-vancouver-canada/stays',
#                 'linkText': 'North Vancouver',
#                 'searchText': 'North Vancouver, Canada'},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/s/homes',
#                 'linkText': 'Stays',
#                 'searchText': ''},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/',
#                 'linkText': 'Airbnb',
#                 'searchText': ''}],
#               'nearbyCities': [],
#               'neighborhoodBreadcrumbDetails': [{'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/north-vancouver-canada/stays',
#                 'linkText': 'North Vancouver',
#                 'searchText': 'North Vancouver, Canada'},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/s/homes',
#                 'linkText': 'Stays',
#                 'searchText': ''},
#                {'__typename': 'SeoBreadcrumbDetails',
#                 'linkRoute': '/',
#                 'linkText': 'Airbnb',
#                 'searchText': ''}],
#               'ogTags': {'__typename': 'SeoOgTags',
#                'ogDescription': 'Evergreen Suite - new cozy 1BR',
#                'ogImage': 'https://a0.muscache.com/im/pictures/airflow/Hosting-888757305688084444/original/13188dbe-9c36-41ec-80e6-aad203f0132d.jpg?im_w=720&width=720&quality=70&auto=webp',
#                'ogTitle': 'Guest suite in North Vancouver · ★5.0 · 1 bedroom · 2 beds · 1 bath',
#                'ogType': 'airbedandbreakfast:listing',
#                'ogUrl': 'https://www.airbnb.ca/rooms/888757305688084444',
#                'ogImageHeight': None,
#                'ogImageWidth': None,
#                'ogVideoUrl': None,
#                'ogVideoHeight': None,
#                'ogVideoWidth': None},
#               'otherPropertyTypes': [{'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6ODg4NzU3MzA1Njg4MDg0NDQz',
#                 'option': 'Apartments',
#                 'url': '/s/North-Vancouver--Canada/homes?property_type_id[]=1'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6ODg4NzU3MzA1Njg4MDg0NDQy',
#                 'option': 'Houses',
#                 'url': '/s/North-Vancouver--Canada/homes?property_type_id[]=2'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6ODg4NzU3MzA1Njg4MDg0NDQx',
#                 'option': 'Bed and breakfasts',
#                 'url': '/s/North-Vancouver--Canada/homes?property_type_id[]=3'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6ODg4NzU3MzA1Njg4MDg0NDA5',
#                 'option': 'Lofts',
#                 'url': '/s/North-Vancouver--Canada/homes?property_type_id[]=35'},
#                {'__typename': 'SeoOtherPropertyType',
#                 'id': 'U2VvT3RoZXJQcm9wZXJ0eVR5cGU6ODg4NzU3MzA1Njg4MDg0NDMz',
#                 'option': 'Villas',
#                 'url': '/s/North-Vancouver--Canada/homes?property_type_id[]=11'}],
#               'propertySearchUrl': '/north-vancouver-canada/stays',
#               'relImageSrc': 'https://a0.muscache.com/im/pictures/airflow/Hosting-888757305688084444/original/13188dbe-9c36-41ec-80e6-aad203f0132d.jpg?im_w=720&width=720&quality=70&auto=webp',
#               'twitterTags': {'__typename': 'SeoTwitterTags',
#                'twitterCard': 'photo',
#                'twitterDescription': None,
#                'twitterImage': 'https://a0.muscache.com/im/pictures/airflow/Hosting-888757305688084444/original/13188dbe-9c36-41ec-80e6-aad203f0132d.jpg?im_w=720&width=720&quality=70&auto=webp',
#                'twitterTitle': None,
#                'twitterUrl': 'https://www.airbnb.ca/rooms/888757305688084444'},
#               'indexInSearchEngines': True},
#              'initialTranslationState': None,
#              'bookingPrefetchData': {'__typename': 'PdpBookingPrefetchData',
#               'isHotelRatePlanEnabled': False,
#               'tpointContent': None,
#               'barPrice': None,
#               'canInstantBook': False,
#               'cancellationPolicies': [{'__typename': 'LegacyPdpCancellationSection',
#                 'cancellation_policy_price_type': None,
#                 'book_it_module_tooltip': 'Add your trip dates to get the cancellation details for this stay.',
#                 'cancellation_policy_id': 4,
#                 'link': '/help/article/2637',
#                 'link_text': 'Get full details',
#                 'localized_cancellation_policy_name': 'Moderate',
#                 'milestones': [],
#                 'subtitles': ['Add your trip dates to get the cancellation details for this stay.'],
#                 'title': ''}],
#               'p3DepositData': None,
#               'p3MessageData': None,
#               'p3CancellationSection': {'__typename': 'LegacyPdpCancellationSection',
#                'cancellationPolicyPriceType': None},
#               'price': None,
#               'productRateSections': None,
#               'p3_display_rate': None,
#               'productItemDetail': None,
#               'ratePlanLoggingEventData': {'__typename': 'LoggingEventData',
#                'loggingId': 'ratePlanInput',
#                'experiments': None,
#                'eventData': None,
#                'eventDataSchemaName': None,
#                'section': None,
#                'component': None}}},
#             'sbuiData': {'__typename': 'StayPDPSBUIData',
#              'sectionConfiguration': {'__typename': 'StayPDPSectionConfiguration',
#               'root': {'__typename': 'PlacementGroupsPerFormFactor',
#                'sections': [{'__typename': 'SectionDataContainer',
#                  'sectionId': 'GUEST_FAVORITE_BANNER',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp.guest_favorite_banner',
#                   'experiments': None,
#                   'eventData': {'productId': 'U3RheUxpc3Rpbmc6ODg4NzU3MzA1Njg4MDg0NDQ0',
#                    'pdpImpressionId': 'p3_1718705519_P3Mn_X6mr702wM1T',
#                    'pdpContext': {'isGoldenLaurel': 'true'}},
#                   'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpReviewsHighlightBannerSection',
#                   'brandDescription': 'One of the most loved homes on Airbnb, according to guests',
#                   'reviewData': {'__typename': 'PdpReviewsHighlightReviewData',
#                    'reviewsCount': '28',
#                    'reviewsCountSubtitle': 'Reviews',
#                    'reviewsCountUnit': None,
#                    'averageRating': '5.0',
#                    'ratingScoreAccessibilityLabel': 'Rated 5.0 out of 5 stars.',
#                    'reviewsCountAccessibilityLabel': '28 reviews',
#                    'loggingEventData': {'__typename': 'LoggingEventData',
#                     'loggingId': 'pdp.guest_favorite_banner',
#                     'eventData': {'productId': 'U3RheUxpc3Rpbmc6ODg4NzU3MzA1Njg4MDg0NDQ0',
#                      'pdpImpressionId': 'p3_1718705519_P3Mn_X6mr702wM1T',
#                      'pdpContext': {'isGoldenLaurel': 'true'}},
#                     'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                     'section': None,
#                     'component': None}},
#                   'tag': 'Guest\nfavourite',
#                   'hasGoldenLaurel': True}},
#                 {'__typename': 'SectionDataContainer',
#                  'sectionId': 'OVERVIEW_DEFAULT_V2',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp.overview_default_v2',
#                   'experiments': None,
#                   'eventData': {'productId': 'U3RheUxpc3Rpbmc6ODg4NzU3MzA1Njg4MDg0NDQ0',
#                    'pdpImpressionId': 'p3_1718705519_P3Mn_X6mr702wM1T',
#                    'pdpContext': {'isGuestFavorite': 'true'}},
#                   'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpOverviewV2Section',
#                   'title': 'Entire guest suite in North Vancouver, Canada',
#                   'overviewItems': [{'__typename': 'PdpSbuiBasicListItem',
#                     'title': '4 guests'},
#                    {'__typename': 'PdpSbuiBasicListItem',
#                     'title': '1 bedroom'},
#                    {'__typename': 'PdpSbuiBasicListItem', 'title': '2 beds'},
#                    {'__typename': 'PdpSbuiBasicListItem', 'title': '1 bath'}],
#                   'reviewData': None}},
#                 {'__typename': 'SectionDataContainer',
#                  'sectionId': 'HOST_OVERVIEW_DEFAULT',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp.host_overview_default',
#                   'experiments': None,
#                   'eventData': {'productId': 'U3RheUxpc3Rpbmc6ODg4NzU3MzA1Njg4MDg0NDQ0',
#                    'pdpImpressionId': 'p3_1718705519_P3Mn_X6mr702wM1T',
#                    'pdpContext': {'isSuperHost': 'true',
#                     'hostId': '195532030'}},
#                   'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpHostOverviewDefaultSection',
#                   'title': 'Hosted by Anja',
#                   'overviewItems': [{'__typename': 'PdpSbuiBasicListItem',
#                     'title': 'Superhost'},
#                    {'__typename': 'PdpSbuiBasicListItem',
#                     'title': '1 year hosting'}],
#                   'hostAvatar': {'__typename': 'Avatar',
#                    'badge': 'SUPER_HOST',
#                    'scrollId': None,
#                    'avatarImage': {'__typename': 'Image',
#                     'baseUrl': 'https://a0.muscache.com/im/pictures/user/User-195532030/original/1ae7b2ae-87dc-42fb-8032-14d80ee5567e.jpeg',
#                     'accessibilityLabel': 'Anja is a superhost. Learn more about Anja.'},
#                    'loggingEventData': {'__typename': 'LoggingEventData',
#                     'loggingId': 'pdp.host_overview_default',
#                     'eventData': {'productId': 'U3RheUxpc3Rpbmc6ODg4NzU3MzA1Njg4MDg0NDQ0',
#                      'pdpImpressionId': 'p3_1718705519_P3Mn_X6mr702wM1T',
#                      'pdpContext': {'isSuperHost': 'true',
#                       'hostId': '195532030'}},
#                     'eventDataSchemaName': 'Pdp.v5.ClientEventData',
#                     'section': None,
#                     'component': None}}}},
#                 {'__typename': 'SectionDataContainer',
#                  'sectionId': 'LUXE_BANNER',
#                  'loggingData': {'__typename': 'LoggingEventData',
#                   'loggingId': 'pdp_platform.luxe_banner',
#                   'experiments': None,
#                   'eventData': None,
#                   'eventDataSchemaName': None,
#                   'section': None,
#                   'component': None},
#                  'sectionData': {'__typename': 'PdpLuxeBannerSection',
#                   'accessibilityLabel': 'Airbnb Luxe',
#                   'brandDescription': 'Extraordinary homes, vetted for quality.'}}]},
#               'aircover': {'__typename': 'PlacementGroupsPerFormFactor',
#                'sections': []}}}}}}},
#         'variables': {'id': 'U3RheUxpc3Rpbmc6ODg4NzU3MzA1Njg4MDg0NDQ0',
#          'pdpSectionsRequest': {'adults': '1',
#           'amenityFilters': None,
#           'bypassTargetings': False,
#           'categoryTag': None,
#           'causeId': None,
#           'children': None,
#           'disasterId': None,
#           'discountedGuestFeeVersion': None,
#           'displayExtensions': None,
#           'federatedSearchId': None,
#           'forceBoostPriorityMessageType': None,
#           'infants': None,
#           'interactionType': None,
#           'layouts': ['SIDEBAR', 'SINGLE_COLUMN'],
#           'pets': 0,
#           'pdpTypeOverride': None,
#           'photoId': None,
#           'preview': False,
#           'previousStateCheckIn': None,
#           'previousStateCheckOut': None,
#           'priceDropSource': None,
#           'privateBooking': False,
#           'promotionUuid': None,
#           'relaxedAmenityIds': None,
#           'searchId': None,
#           'selectedCancellationPolicyId': None,
#           'selectedRatePlanId': None,
#           'splitStays': None,
#           'staysBookingMigrationEnabled': False,
#           'translateUgc': None,
#           'useNewSectionWrapperApi': False,
#           'sectionIds': None,
#           'checkIn': None,
#           'checkOut': None,
#           'p3ImpressionId': 'p3_1718705519_P3Mn_X6mr702wM1T'}}}]]}],
#    ['NiobeMinimalistCacheToken', [], 1]],
#   'root > core-guest-spa > app': [],
#   'root > core-guest-spa > app > /rooms/:id(\\d+)/:subpageId?/:nestedSubpageId?': []}]

# %%
parcing_dict = get_listing_presentation(input, listing_id='888757305688084444')

with open('888757305688084444_expected_presentation.jsonl', 'w') as file:  
    file.write(json.dumps(parcing_dict) + '\n')

# %%
parsed_result = read_jsonl('888757305688084444_parsed_result.jsonl')[0]
parsed_result
# Out:
# {'listing_id': '888757305688084444',
#  'checking_in_and_out_house_rule': ['Check-in after 3:00 p.m.',
#   'Checkout before 11:00 a.m.',
#   'Self check-in with keypad'],
#  'during_your_stay_house_rule': ['4 guests maximum',
#   'No pets',
#   'Quiet hours: 11:00 p.m.–6:00 a.m.',
#   'No parties or events',
#   'No commercial photography',
#   'No smoking',
#   'Additional rules',
#   'Treat the place like your own.'],
#  'scenic_views_amenities': ['Garden view'],
#  'bathroom_amenities': ['Hair dryer',
#   'Cleaning products',
#   'Shampoo',
#   'Conditioner',
#   'Body soap',
#   'Bidet',
#   'Hot water'],
#  'bedroom_and_laundry_amenities': ['Washer',
#   'Free dryer – In unit',
#   'Essentials',
#   'Hangers',
#   'Bed linens',
#   'Extra pillows and blankets',
#   'Room-darkening shades',
#   'Clothing storage: closet'],
#  'entertainment_amenities': ['TV'],
#  'family_amenities': ['Pack ’n play/Travel crib – available upon request',
#   'Standalone high chair – available upon request',
#   'Children’s dinnerware'],
#  'heating_and_cooling_amenities': ['Central heating', 'Radiant heating'],
#  'home_safety_amenities': ['Smoke alarm',
#   'Carbon monoxide alarm',
#   'Fire extinguisher'],
#  'internet_and_office_amenities': ['Wifi', 'Dedicated workspace'],
#  'kitchen_and_dining_amenities': ['Kitchen',
#   'Refrigerator',
#   'Microwave',
#   'Cooking basics',
#   'Dishes and silverware',
#   'Freezer',
#   'Dishwasher',
#   'Stainless steel electric stove',
#   'Stainless steel oven',
#   'Hot water kettle',
#   'Coffee maker: French press, Nespresso',
#   'Wine glasses',
#   'Dining table'],
#  'location_features_amenities': ['Private entrance'],
#  'outdoor_amenities': ['Private patio or balcony', 'Outdoor dining area'],
#  'parking_and_facilities_amenities': ['Free parking on premises',
#   'Free street parking'],
#  'services_amenities': ['Self check-in', 'Keypad'],
#  'not_included_amenities': ['Exterior security cameras on property',
#   'Air conditioning'],
#  'place_description': 'Use our newly renovated place as your basecamp for your North Vancouver adventures. Located in Blueridge at the foot of Mt Seymour, close to world class mtb/hiking trails,  Deep Cove, and 25min to Vancouver, our 1BR garden level suite is ideal for nature lovers, professionals, and young families.  Fully equipped kitchen, office nook, queen bed and queen size pull-out couch, washer & dryer, outside patio overlooking the "evergreen" backyard. Bolt-in bike rack on covered patio to store bikes.',
#  'the_space_description': "You'll find your own private entrance at the back of the house, with keyless entry and a patio for you to use.<br /><br />The suite includes a full-size kitchen with new stainless steel fridge, oven, dishwasher, microwave, and Nespresso machine (a French press is also available).  You'll find a toaster, water boiler, and all the cooking and dining utensils available to prepare and enjoy your meals. <br /><br />The cozy main living space comes with an expandable dining table, four chairs, a sofa bed that doubles as a queen size bed and a lounge chair to chill.<br /><br />In the bedroom you will find a comfortable queen size bed, a wardrobe, as well as a dedicated office space with a desk. In addition there is a smart TV with Netflix access for your entertainment. <br /><br />The bathroom includes a shower and (optional) Bidet style toilet. Outside the bathroom, you'll find a new washer and dryer for you to use. <br /><br />The patio looks over the backyard with lots of trees and old tree stumps and includes a little table and four chairs to relax outside. You can also find a bolted bike stand there.",
#  'guest_access_description': 'You have a private entrance to the suite with a coded non-key entrance, and a covered patio. The backyard is for us to use.',
#  'other_things_to_note_description': 'We live in the floor above the suite with our two small girls (4 and 6). Although we did soundproof the place through the renovation, you will hear them running around upstairs. They are normally in bed between 9pm and 6am.  They might be running around the backyard in the summer, and use the trampoline as well. If you are looking for a very quiet place, our suite might not be the right place.<br /><br />We love mountain biking, skiing, and pretty much most outdoor sports. We came here and stayed because of the lifestyle and happily share our knowledge and provide any tips or what to do/'}

# %%
expected_house_rules = dict((key, parsed_result[key]) for key in parsed_result.keys() if key.endswith('_house_rule'))
expected_house_rules
# Out:
# {'checking_in_and_out_house_rule': ['Check-in after 3:00 p.m.',
#   'Checkout before 11:00 a.m.',
#   'Self check-in with keypad'],
#  'during_your_stay_house_rule': ['4 guests maximum',
#   'No pets',
#   'Quiet hours: 11:00 p.m.–6:00 a.m.',
#   'No parties or events',
#   'No commercial photography',
#   'No smoking',
#   'Additional rules',
#   'Treat the place like your own.']}

# %%
expected_amenities = dict((key, parsed_result[key]) for key in parsed_result.keys() if key.endswith('_amenities'))
expected_amenities
# Out:
# {'scenic_views_amenities': ['Garden view'],
#  'bathroom_amenities': ['Hair dryer',
#   'Cleaning products',
#   'Shampoo',
#   'Conditioner',
#   'Body soap',
#   'Bidet',
#   'Hot water'],
#  'bedroom_and_laundry_amenities': ['Washer',
#   'Free dryer – In unit',
#   'Essentials',
#   'Hangers',
#   'Bed linens',
#   'Extra pillows and blankets',
#   'Room-darkening shades',
#   'Clothing storage: closet'],
#  'entertainment_amenities': ['TV'],
#  'family_amenities': ['Pack ’n play/Travel crib – available upon request',
#   'Standalone high chair – available upon request',
#   'Children’s dinnerware'],
#  'heating_and_cooling_amenities': ['Central heating', 'Radiant heating'],
#  'home_safety_amenities': ['Smoke alarm',
#   'Carbon monoxide alarm',
#   'Fire extinguisher'],
#  'internet_and_office_amenities': ['Wifi', 'Dedicated workspace'],
#  'kitchen_and_dining_amenities': ['Kitchen',
#   'Refrigerator',
#   'Microwave',
#   'Cooking basics',
#   'Dishes and silverware',
#   'Freezer',
#   'Dishwasher',
#   'Stainless steel electric stove',
#   'Stainless steel oven',
#   'Hot water kettle',
#   'Coffee maker: French press, Nespresso',
#   'Wine glasses',
#   'Dining table'],
#  'location_features_amenities': ['Private entrance'],
#  'outdoor_amenities': ['Private patio or balcony', 'Outdoor dining area'],
#  'parking_and_facilities_amenities': ['Free parking on premises',
#   'Free street parking'],
#  'services_amenities': ['Self check-in', 'Keypad'],
#  'not_included_amenities': ['Exterior security cameras on property',
#   'Air conditioning']}

# %%
expected_description = dict((key, parsed_result[key]) for key in parsed_result.keys() if key.endswith('_description'))
expected_description
# Out:
# {'place_description': 'Use our newly renovated place as your basecamp for your North Vancouver adventures. Located in Blueridge at the foot of Mt Seymour, close to world class mtb/hiking trails,  Deep Cove, and 25min to Vancouver, our 1BR garden level suite is ideal for nature lovers, professionals, and young families.  Fully equipped kitchen, office nook, queen bed and queen size pull-out couch, washer & dryer, outside patio overlooking the "evergreen" backyard. Bolt-in bike rack on covered patio to store bikes.',
#  'the_space_description': "You'll find your own private entrance at the back of the house, with keyless entry and a patio for you to use.<br /><br />The suite includes a full-size kitchen with new stainless steel fridge, oven, dishwasher, microwave, and Nespresso machine (a French press is also available).  You'll find a toaster, water boiler, and all the cooking and dining utensils available to prepare and enjoy your meals. <br /><br />The cozy main living space comes with an expandable dining table, four chairs, a sofa bed that doubles as a queen size bed and a lounge chair to chill.<br /><br />In the bedroom you will find a comfortable queen size bed, a wardrobe, as well as a dedicated office space with a desk. In addition there is a smart TV with Netflix access for your entertainment. <br /><br />The bathroom includes a shower and (optional) Bidet style toilet. Outside the bathroom, you'll find a new washer and dryer for you to use. <br /><br />The patio looks over the backyard with lots of trees and old tree stumps and includes a little table and four chairs to relax outside. You can also find a bolted bike stand there.",
#  'guest_access_description': 'You have a private entrance to the suite with a coded non-key entrance, and a covered patio. The backyard is for us to use.',
#  'other_things_to_note_description': 'We live in the floor above the suite with our two small girls (4 and 6). Although we did soundproof the place through the renovation, you will hear them running around upstairs. They are normally in bed between 9pm and 6am.  They might be running around the backyard in the summer, and use the trampoline as well. If you are looking for a very quiet place, our suite might not be the right place.<br /><br />We love mountain biking, skiing, and pretty much most outdoor sports. We came here and stayed because of the lifestyle and happily share our knowledge and provide any tips or what to do/'}

# %% [markdown]
# For more data overview see here:
#
# https://github.com/CodeForBc/airbnb-ai/blob/main/notebooks/experiments/1.0_ab_read_all_data_and_some_eda.ipynb
