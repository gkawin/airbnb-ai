# %%
import pandas as pd

# Replace 'yourfile.csv' with the path to your .csv file
df = pd.read_csv('D:/airbnb-ai/data/raw_data/Xavier_rawdata_2024-07-08_Kelowna_Chilliwack_Abbotsford.csv')

# Display the first few rows of the dataframe
df.head()
# Out:
#          id     userId                                               name  \
# 0  26083976   79099075     🤴 DT King Suite with parking steps from beach🤴
# 1  30961277  200869522     Treehouse Suite steps to KGH Hospital & beach!
# 2  33994731   43968564  Luke’s Downtown, Double Garage, Pet Friendly H...
# 3  40489112  163114314                         "The Cubby on Christleton"
# 4  52189683   58082001      Central, Private Guest Suite, Rainfall Shower
#
#                address     city  isSuperhost        lat         lng  persons  \
# 0  Kelowna, BC, Canada  Kelowna         True  49.890410 -119.492370        2
# 1  Kelowna, BC, Canada  Kelowna         True  49.870470 -119.492720        1
# 2  Kelowna, BC, Canada  Kelowna         True  49.890027 -119.487048        4
# 3  Kelowna, BC, Canada  Kelowna         True  49.873030 -119.489650        2
# 4  Kelowna, BC, Canada  Kelowna         True  49.901370 -119.466520        2
#
#    rating  ...  price_currency price_rate price_total bathrooms bedrooms beds  \
# 0    4.86  ...             CAD        245         735       1.0        0    1
# 1    5.00  ...             CAD        197         591       1.0        0    2
# 2    4.98  ...             CAD        270         808       2.0        2    2
# 3    4.76  ...             CAD        179         537       1.0        1    1
# 4    4.71  ...             CAD        182         544       1.0        1    2
#
#      previewAmenities                                    url  \
# 0  Free parking, Wifi  https://www.airbnb.com/rooms/26083976
# 1  Free parking, Wifi  https://www.airbnb.com/rooms/30961277
# 2  Free parking, Wifi  https://www.airbnb.com/rooms/33994731
# 3  Free parking, Wifi  https://www.airbnb.com/rooms/40489112
# 4  Free parking, Wifi  https://www.airbnb.com/rooms/52189683
#
#                                               images  \
# 0  ['https://a0.muscache.com/im/pictures/c996bf46...
# 1  ['https://a0.muscache.com/im/pictures/47c83d63...
# 2  ['https://a0.muscache.com/im/pictures/hosting/...
# 3  ['https://a0.muscache.com/im/pictures/15c67c71...
# 4  ['https://a0.muscache.com/im/pictures/miso/Hos...
#
#                                           amenityIds
# 0  [1, 4, 5, 8, 9, 139, 77, 15, 79, 657, 21, 85, ...
# 1  [1, 2, 4, 5, 9, 137, 139, 145, 657, 146, 280, ...
# 2  [1, 4, 5, 133, 8, 392, 9, 137, 394, 522, 12, 1...
# 3  [1, 4, 8, 9, 77, 23, 89, 90, 91, 93, 30, 33, 3...
# 4  [1, 4, 5, 9, 137, 77, 657, 146, 85, 86, 23, 89...
#
# [5 rows x 25 columns]

# %%
df.info()

# %%
df.describe()

# %%
df.head()

# %%
import matplotlib.pyplot as plt

df.plot(kind='line')  # or any other plot type
plt.show()
